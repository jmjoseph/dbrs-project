# %% [markdown]
# # PART 1: SOURCING AND CLEANING DATA
#
# In this notebook, I'll be creating 3 dataframes to analyze 311 complaints in NYC in 2017. The databases are the following:
#
# 1. NYC 311 Service Request Data
# 2. 2010 Census Population Data
# 3. Zip codes for NYC boroughs

# %%
import os
import sys
import time
import requests

import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

from io import StringIO

# %%
def timeElapsed(start):
    elapsed = time.time() - start
    print(time.strftime("%M:%S", time.gmtime(elapsed)))

# %% [markdown]
# ## NYC 311 Service Request Data
# First, I'll take a few probes at the NYC 311 database to see what I'm working with. Much of this has been removed for readability.

# %%
pd.set_option('display.max_columns', 60)

# Start off with a simple call of 2019 complaints to get a feel for the dataset
apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?$where=date_extract_y(created_date)=2019"

resp = requests.get(apiURL)
csvIO = StringIO(resp.text)
resp_df = pd.read_csv(csvIO)
resp_df
# Out:
#      address_type agency                                        agency_name  \
# 0         ADDRESS   DSNY                               BCC - Brooklyn South
# 1         ADDRESS    DOT                       Department of Transportation
# 2         ADDRESS   DSNY                           Department of Sanitation
# 3         ADDRESS   DSNY                           Department of Sanitation
# 4    INTERSECTION   DSNY                                  BCC - Queens East
# 5         ADDRESS   DSNY                           Department of Sanitation
# 6    INTERSECTION   DSNY                                           Bronx 03
# 7         ADDRESS   DSNY                                        BCC - Bronx
# 8         ADDRESS   DSNY                           Department of Sanitation
# 9    INTERSECTION   DSNY                                  A - Staten Island
# 10        ADDRESS   DSNY                           Department of Sanitation
# 11        ADDRESS   DSNY                           Department of Sanitation
# 12        ADDRESS   DSNY                           Department of Sanitation
# 13        ADDRESS   DSNY                           Department of Sanitation
# 14        ADDRESS   DSNY                           Department of Sanitation
# 15        ADDRESS   DSNY                           Department of Sanitation
# 16        ADDRESS    DOT                       Department of Transportation
# 17        ADDRESS   DSNY                           Department of Sanitation
# 18        ADDRESS   DSNY                           Department of Sanitation
# 19        ADDRESS   DSNY                           Department of Sanitation
# 20        ADDRESS   DSNY                           Department of Sanitation
# 21        ADDRESS   DSNY                           Department of Sanitation
# 22        ADDRESS   DSNY                           Department of Sanitation
# 23        ADDRESS   DSNY                           Department of Sanitation
# 24        ADDRESS   DSNY                           Department of Sanitation
# 25        ADDRESS   DSNY                           Department of Sanitation
# 26        ADDRESS   DSNY                           Department of Sanitation
# 27        ADDRESS   DSNY                           Department of Sanitation
# 28        ADDRESS   DSNY                           Department of Sanitation
# 29        ADDRESS   DSNY                           Department of Sanitation
# ..            ...    ...                                                ...
# 970       ADDRESS   NYPD                    New York City Police Department
# 971       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 972       ADDRESS   NYPD                    New York City Police Department
# 973       ADDRESS   NYPD                    New York City Police Department
# 974       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 975       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 976       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 977       ADDRESS   NYPD                    New York City Police Department
# 978       ADDRESS   DSNY                                        BCC - Bronx
# 979           NaN    DOT                       Department of Transportation
# 980       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 981       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 982  INTERSECTION    DOT                       Department of Transportation
# 983       ADDRESS    DEP             Department of Environmental Protection
# 984       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 985       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 986       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 987       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 988       ADDRESS   DSNY                           Department of Sanitation
# 989       ADDRESS    DOB                            Department of Buildings
# 990       ADDRESS   NYPD                    New York City Police Department
# 991  INTERSECTION    DOT                       Department of Transportation
# 992       ADDRESS   DSNY                           Department of Sanitation
# 993       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 994       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 995       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 996       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 997       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 998       ADDRESS    DOF                                 Payment Operations
# 999       ADDRESS    HPD  Department of Housing Preservation and Develop...
#
#               bbl        borough  bridge_highway_direction  \
# 0    3.071530e+09       BROOKLYN                       NaN
# 1    1.015340e+09      MANHATTAN                       NaN
# 2    1.007790e+09      MANHATTAN                       NaN
# 3    2.054730e+09          BRONX                       NaN
# 4             NaN         QUEENS                       NaN
# 5    3.055890e+09       BROOKLYN                       NaN
# 6             NaN          BRONX                       NaN
# 7    2.046680e+09          BRONX                       NaN
# 8    3.035190e+09       BROOKLYN                       NaN
# 9             NaN  STATEN ISLAND                       NaN
# 10   1.007650e+09      MANHATTAN                       NaN
# 11   5.000690e+09  STATEN ISLAND                       NaN
# 12   3.013050e+09       BROOKLYN                       NaN
# 13   1.000168e+09      MANHATTAN                       NaN
# 14   2.031460e+09          BRONX                       NaN
# 15   4.011760e+09         QUEENS                       NaN
# 16            NaN         QUEENS                       NaN
# 17   3.018340e+09       BROOKLYN                       NaN
# 18   5.067250e+09  STATEN ISLAND                       NaN
# 19   3.049860e+09       BROOKLYN                       NaN
# 20   3.086780e+09       BROOKLYN                       NaN
# 21   3.051590e+09       BROOKLYN                       NaN
# 22   1.012200e+09      MANHATTAN                       NaN
# 23   2.037420e+09          BRONX                       NaN
# 24   3.048470e+09       BROOKLYN                       NaN
# 25   1.003940e+09      MANHATTAN                       NaN
# 26   4.056430e+09         QUEENS                       NaN
# 27   1.021690e+09      MANHATTAN                       NaN
# 28   5.052090e+09  STATEN ISLAND                       NaN
# 29   3.019720e+09       BROOKLYN                       NaN
# ..            ...            ...                       ...
# 970  4.053290e+09         QUEENS                       NaN
# 971  3.014910e+09       BROOKLYN                       NaN
# 972           NaN          BRONX                       NaN
# 973  3.066690e+09       BROOKLYN                       NaN
# 974  4.019430e+09         QUEENS                       NaN
# 975  3.018000e+09       BROOKLYN                       NaN
# 976  2.028760e+09          BRONX                       NaN
# 977  4.051510e+09         QUEENS                       NaN
# 978  2.050400e+09          BRONX                       NaN
# 979           NaN    Unspecified                       NaN
# 980  4.017360e+09         QUEENS                       NaN
# 981  1.022390e+09      MANHATTAN                       NaN
# 982           NaN         QUEENS                       NaN
# 983  1.019110e+09      MANHATTAN                       NaN
# 984  2.042380e+09          BRONX                       NaN
# 985  2.029580e+09          BRONX                       NaN
# 986  4.015070e+09         QUEENS                       NaN
# 987  2.035190e+09          BRONX                       NaN
# 988  4.070270e+09         QUEENS                       NaN
# 989  5.000160e+09  STATEN ISLAND                       NaN
# 990  4.016120e+09         QUEENS                       NaN
# 991           NaN       BROOKLYN                       NaN
# 992  4.159650e+09         QUEENS                       NaN
# 993  1.021360e+09      MANHATTAN                       NaN
# 994  3.050840e+09       BROOKLYN                       NaN
# 995  4.021160e+09         QUEENS                       NaN
# 996  2.046420e+09          BRONX                       NaN
# 997  3.015620e+09       BROOKLYN                       NaN
# 998  1.004818e+09      MANHATTAN                       NaN
# 999  1.021360e+09      MANHATTAN                       NaN
#
#      bridge_highway_name bridge_highway_segment             city  \
# 0                    NaN                    NaN         BROOKLYN
# 1                    NaN                    NaN         NEW YORK
# 2                    NaN                    NaN         NEW YORK
# 3                    NaN                    NaN            BRONX
# 4                    NaN                    NaN   Queens Village
# 5                    NaN                    NaN         BROOKLYN
# 6                    NaN                    NaN            BRONX
# 7                    NaN                    NaN            BRONX
# 8                    NaN                    NaN         BROOKLYN
# 9                    NaN                    NaN    STATEN ISLAND
# 10                   NaN                    NaN         NEW YORK
# 11                   NaN                    NaN    STATEN ISLAND
# 12                   NaN                    NaN         BROOKLYN
# 13                   NaN                    NaN         NEW YORK
# 14                   NaN                    NaN            BRONX
# 15                   NaN                    NaN    East Elmhurst
# 16                   NaN                    NaN  Jackson Heights
# 17                   NaN                    NaN         BROOKLYN
# 18                   NaN                    NaN    STATEN ISLAND
# 19                   NaN                    NaN         BROOKLYN
# 20                   NaN                    NaN         BROOKLYN
# 21                   NaN                    NaN         BROOKLYN
# 22                   NaN                    NaN         NEW YORK
# 23                   NaN                    NaN            BRONX
# 24                   NaN                    NaN         BROOKLYN
# 25                   NaN                    NaN         NEW YORK
# 26                   NaN                    NaN    Fresh Meadows
# 27                   NaN                    NaN         NEW YORK
# 28                   NaN                    NaN    STATEN ISLAND
# 29                   NaN                    NaN         BROOKLYN
# ..                   ...                    ...              ...
# 970                  NaN                    NaN         FLUSHING
# 971                  NaN                    NaN         BROOKLYN
# 972                  NaN                    NaN            BRONX
# 973                  NaN                    NaN         BROOKLYN
# 974                  NaN                    NaN           Corona
# 975                  NaN                    NaN         BROOKLYN
# 976                  NaN                    NaN            BRONX
# 977                  NaN                    NaN         FLUSHING
# 978                  NaN                    NaN            BRONX
# 979                  NaN                    NaN              NaN
# 980                  NaN                    NaN           Corona
# 981                  NaN                    NaN         NEW YORK
# 982                  NaN                    NaN          Jamaica
# 983                  NaN                    NaN         NEW YORK
# 984                  NaN                    NaN            BRONX
# 985                  NaN                    NaN            BRONX
# 986                  NaN                    NaN         Elmhurst
# 987                  NaN                    NaN            BRONX
# 970         STATION ROAD               SANFORD AVENUE
# 971                  NaN                          NaN
# 972        NELSON AVENUE                 OGDEN AVENUE
# 973      HIGHLAWN AVENUE                     AVENUE S
# 974                  NaN                          NaN
# 975                  NaN                          NaN
# 976                  NaN                          NaN
# 977        COLDEN STREET            KISSENA BOULEVARD
# 978      EAST 237 STREET                NEREID AVENUE
# 979          MAIN STREET                          NaN
# 980                  NaN                          NaN
# 981                  NaN                          NaN
# 982                  NaN                          NaN
# 983            LENOX AVE  ADAM CLAYTON POWELL JR BLVD
# 984                  NaN                          NaN
# 985                  NaN                          NaN
# 986                  NaN                          NaN
# 987                  NaN                          NaN
# 988            81 AVENUE              GOETHALS AVENUE
# 989                  NaN                          NaN
# 990   JUNCTION BOULEVARD                     97 PLACE
# 991                  NaN                          NaN
# 992  BEACH CHANNEL DRIVE               EDGEMERE DRIVE
# 993                  NaN                          NaN
# 994                  NaN                          NaN
# 995                  NaN                          NaN
# 996                  NaN                          NaN
# 997                  NaN                          NaN
# 998       KENMARE STREET                SPRING STREET
# 999                  NaN                          NaN
#
#                                         descriptor                 due_date  \
# 0                                  12 Dead Animals                      NaN
# 1                                          Pothole                      NaN
# 2              Request Large Bulky Item Collection                      NaN
# 3              Request Large Bulky Item Collection                      NaN
# 4                                  12 Dead Animals                      NaN
# 5              Request Large Bulky Item Collection                      NaN
# 6                                  12 Dead Animals                      NaN
# 7                                  12 Dead Animals                      NaN
# 8              Request Large Bulky Item Collection                      NaN
# 9                                E3 Dirty Sidewalk                      NaN
# 10             Request Large Bulky Item Collection                      NaN
# 11             Request Large Bulky Item Collection                      NaN
# 12             Request Large Bulky Item Collection                      NaN
# 13             Request Large Bulky Item Collection                      NaN
# 14             Request Large Bulky Item Collection                      NaN
# 15             Request Large Bulky Item Collection                      NaN
# 16                                         Pothole                      NaN
# 17             Request Large Bulky Item Collection                      NaN
# 18             Request Large Bulky Item Collection                      NaN
# 19             Request Large Bulky Item Collection                      NaN
# 20             Request Large Bulky Item Collection                      NaN
# 21             Request Large Bulky Item Collection                      NaN
# 22             Request Large Bulky Item Collection                      NaN
# 23             Request Large Bulky Item Collection                      NaN
# 24             Request Large Bulky Item Collection                      NaN
# 25             Request Large Bulky Item Collection                      NaN
# 26             Request Large Bulky Item Collection                      NaN
# 27             Request Large Bulky Item Collection                      NaN
# 28             Request Large Bulky Item Collection                      NaN
# 29             Request Large Bulky Item Collection                      NaN
# ..                                             ...                      ...
# 970                                Blocked Hydrant  2019-01-24T01:16:32.000
# 971                                 APARTMENT ONLY                      NaN
# 972                                      No Access  2019-01-23T22:11:26.000
# 973                   Commercial Overnight Parking  2019-01-24T06:02:14.000
# 974                                 APARTMENT ONLY                      NaN
# 975                                ENTIRE BUILDING                      NaN
# 976                                ENTIRE BUILDING                      NaN
# 977                                      No Access  2019-01-24T06:32:18.000
# 978                     1RG Missed Recycling Paper                      NaN
# 979                                  Other/Unknown  2019-02-06T13:41:33.000
# 980                                     HEAVY FLOW                      NaN
# 981                                 APARTMENT ONLY                      NaN
# 982                               Street Light Out                      NaN
# 983                      Leak (Use Comments) (WA2)                      NaN
# 984                                 APARTMENT ONLY                      NaN
# 985                                       LIGHTING                      NaN
# 986                                ENTIRE BUILDING                      NaN
# 987                                 APARTMENT ONLY                      NaN
# 988            Request Large Bulky Item Collection                      NaN
# 989  Cons - Contrary/Beyond Approved Plans/Permits                      NaN
# 990                                      No Access  2019-01-23T22:16:40.000
# 991                                Veh Signal Lamp                      NaN
# 992            Request Large Bulky Item Collection                      NaN
# 993                                 APARTMENT ONLY                      NaN
# 994                                 APARTMENT ONLY                      NaN
# 995                                ENTIRE BUILDING                      NaN
# 996                                 APARTMENT ONLY                      NaN
# 997                           BELL/BUZZER/INTERCOM                      NaN
# 998                   Refund/Credit Info or Status  2019-02-02T10:59:58.000
# 999                                 APARTMENT ONLY                      NaN
#
#     facility_type               incident_address  incident_zip  \
# 0     DSNY Garage          2254 EAST    2 STREET       11223.0
# 1             NaN           224 EAST   89 STREET       10128.0
# 2             NaN           249 WEST   29 STREET       10001.0
# 3             NaN          3224 LAFAYETTE AVENUE       10465.0
# 4     DSNY Garage                            NaN       11427.0
# 5             NaN                 1263 41 STREET       11218.0
# 6             NaN                            NaN       10456.0
# 7     DSNY Garage           738 EAST  221 STREET       10467.0
# 8             NaN    481 THOMAS S BOYLAND STREET       11212.0
# 9             NaN                            NaN       10309.0
# 10            NaN           200 WEST   16 STREET       10011.0
# 11            NaN           237 VAN BUREN STREET       10301.0
# 12            NaN          366 MONTGOMERY STREET       11225.0
# 13            NaN               380 RECTOR PLACE       10280.0
# 14            NaN           312 EAST  184 STREET       10458.0
# 15            NaN                32-08 81 STREET       11370.0
# 16            NaN                35-41 85 STREET       11372.0
# 17            NaN            398 TOMPKINS AVENUE       11216.0
# 18            NaN            144 COMMODORE DRIVE       10309.0
# 19            NaN           738 EAST   40 STREET       11210.0
# 20            NaN       3126 CONEY ISLAND AVENUE       11235.0
# 21            NaN           410 EAST   17 STREET       11226.0
# 22            NaN            606 COLUMBUS AVENUE       10024.0
# 23            NaN               1122 WARD AVENUE       10472.0
# 24            NaN                 593 LENOX ROAD       11203.0
# 25            NaN                   185 AVENUE C       10009.0
# 26            NaN               50-22 189 STREET       11365.0
# 27            NaN           607 WEST  190 STREET       10040.0
# 28            NaN              321 NELSON AVENUE       10308.0
# 29            NaN               191 GATES AVENUE       11238.0
# ..            ...                            ...           ...
# 970      Precinct               41-06 157 STREET       11355.0
# 971           NaN              841 HALSEY STREET       11233.0
# 972      Precinct            126 WEST 167 STREET       10452.0
# 973      Precinct            1840 WEST 11 STREET       11223.0
# 974           NaN               104-11 53 AVENUE       11368.0
# 975           NaN           477 LEXINGTON AVENUE       11221.0
# 976           NaN  1652 DR M L KING JR BOULEVARD       10453.0
# 977      Precinct         137-54 LABURNAM AVENUE       11355.0
# 978   DSNY Garage            4383 MATILDA AVENUE       10466.0
# 979           NaN                        61 ROAD           NaN
# 980           NaN               34-21 102 STREET       11368.0
# 981           NaN               89 SEAMAN AVENUE       10034.0
# 982           NaN                            NaN       11432.0
# 981  POINT (-73.924792460137 40.868177314864)               NaN
# 982  POINT (-73.781599031336 40.717986988608)               NaN
# 983  POINT (-73.946414233829 40.809051861983)               NaN
# 984   POINT (-73.82863539652 40.851653011156)               NaN
# 985   POINT (-73.887507824882 40.84088109907)               NaN
# 986  POINT (-73.881877603963 40.744914143625)               NaN
# 987  POINT (-73.865293978077 40.814914223584)               NaN
# 988  POINT (-73.800366678417 40.721010112144)               NaN
# 989  POINT (-74.077486822434 40.639826716694)               NaN
# 990  POINT (-73.867994906757 40.746386724905)               NaN
# 991  POINT (-73.998595158911 40.620502053478)               NaN
# 992  POINT (-73.774877314058 40.596547313066)               NaN
# 993  POINT (-73.944836828408 40.838117670583)               NaN
# 994  POINT (-73.953333327286 40.652461128591)               NaN
# 995  POINT (-73.854758821106 40.729095298957)               NaN
# 996  POINT (-73.867354307047 40.879614879391)               NaN
# 997   POINT (-73.916213933545 40.67780732829)               NaN
# 998  POINT (-73.996460929452 40.721496034555)               NaN
# 999  POINT (-73.946517303203 40.838126696195)               NaN
#
#      location_city  location_state         location_type  location_zip  \
# 0              NaN             NaN              Sidewalk           NaN
# 1              NaN             NaN                   NaN           NaN
# 2              NaN             NaN              Sidewalk           NaN
# 3              NaN             NaN              Sidewalk           NaN
# 4              NaN             NaN              Sidewalk           NaN
# 5              NaN             NaN              Sidewalk           NaN
# 6              NaN             NaN              Sidewalk           NaN
# 7              NaN             NaN              Sidewalk           NaN
# 8              NaN             NaN              Sidewalk           NaN
# 9              NaN             NaN              Sidewalk           NaN
# 10             NaN             NaN              Sidewalk           NaN
# 11             NaN             NaN              Sidewalk           NaN
# 12             NaN             NaN              Sidewalk           NaN
# 13             NaN             NaN              Sidewalk           NaN
# 14             NaN             NaN              Sidewalk           NaN
# 15             NaN             NaN              Sidewalk           NaN
# 16             NaN             NaN                   NaN           NaN
# 17             NaN             NaN              Sidewalk           NaN
# 18             NaN             NaN              Sidewalk           NaN
# 19             NaN             NaN              Sidewalk           NaN
# 20             NaN             NaN              Sidewalk           NaN
# 21             NaN             NaN              Sidewalk           NaN
# 22             NaN             NaN              Sidewalk           NaN
# 23             NaN             NaN              Sidewalk           NaN
# 24             NaN             NaN              Sidewalk           NaN
# 25             NaN             NaN              Sidewalk           NaN
# 26             NaN             NaN              Sidewalk           NaN
# 27             NaN             NaN              Sidewalk           NaN
# 28             NaN             NaN              Sidewalk           NaN
# 29             NaN             NaN              Sidewalk           NaN
# ..             ...             ...                   ...           ...
# 970            NaN             NaN       Street/Sidewalk           NaN
# 971            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 972            NaN             NaN       Street/Sidewalk           NaN
# 973            NaN             NaN       Street/Sidewalk           NaN
# 974            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 975            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 976            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 977            NaN             NaN       Street/Sidewalk           NaN
# 978            NaN             NaN              Sidewalk           NaN
# 979            NaN             NaN                Street           NaN
# 980            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 981            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 982            NaN             NaN                   NaN           NaN
# 983            NaN             NaN                   NaN           NaN
# 984            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 985            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 986            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 987            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 988            NaN             NaN              Sidewalk           NaN
# 989            NaN             NaN                   NaN           NaN
# 990            NaN             NaN       Street/Sidewalk           NaN
# 991            NaN             NaN                   NaN           NaN
# 992            NaN             NaN              Sidewalk           NaN
# 993            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 994            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 995            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 996            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 997            NaN             NaN  RESIDENTIAL BUILDING           NaN
# 998            NaN             NaN      Property Address           NaN
# 999            NaN             NaN  RESIDENTIAL BUILDING           NaN
#
#      longitude open_data_channel_type   park_borough park_facility_name  \
# 0   -73.968998                  PHONE       BROOKLYN        Unspecified
# 1   -73.951861                UNKNOWN      MANHATTAN        Unspecified
# 2   -73.994301                  PHONE      MANHATTAN        Unspecified
# 3   -73.818830                  PHONE          BRONX        Unspecified
# 4   -73.754374                  PHONE         QUEENS        Unspecified
# 5   -73.988347                  PHONE       BROOKLYN        Unspecified
# 6   -73.899021                  PHONE          BRONX        Unspecified
# 7   -73.860824                  PHONE          BRONX        Unspecified
# 8   -73.913392                  PHONE       BROOKLYN        Unspecified
# 9   -74.234792                 ONLINE  STATEN ISLAND        Unspecified
# 10  -73.999145                  PHONE      MANHATTAN        Unspecified
# 11  -74.097195                  PHONE  STATEN ISLAND        Unspecified
# 12  -73.952708                  PHONE       BROOKLYN        Unspecified
# 13  -74.017764                  PHONE      MANHATTAN        Unspecified
# 14  -73.896866                  PHONE          BRONX        Unspecified
# 15  -73.886617                  PHONE         QUEENS        Unspecified
# 16  -73.881819                UNKNOWN         QUEENS        Unspecified
# 17  -73.943991                  PHONE       BROOKLYN        Unspecified
# 18  -74.203320                  PHONE  STATEN ISLAND        Unspecified
# 19  -73.938575                  PHONE       BROOKLYN        Unspecified
# 20  -73.959796                  PHONE       BROOKLYN        Unspecified
# 21  -73.962447                  PHONE       BROOKLYN        Unspecified
# 22  -73.970594                  PHONE      MANHATTAN        Unspecified
# 23  -73.876890                  PHONE          BRONX        Unspecified
# ...
# 982        2019-01-22T13:15:00.000
# 983        2019-01-23T13:57:00.000
# 984        2019-01-23T21:08:59.000
# 985        2019-01-23T13:49:19.000
# 986        2019-01-23T02:09:51.000
# 987        2019-01-23T13:05:03.000
# 988        2019-01-30T00:00:00.000
# 989        2019-01-22T00:00:00.000
# 990        2019-01-23T15:01:29.000
# 991        2019-01-25T17:55:00.000
# 992        2019-01-31T00:00:00.000
# 993        2019-01-23T11:20:45.000
# 994        2019-01-23T21:59:33.000
# 995        2019-01-23T12:03:53.000
# 996        2019-01-23T02:10:46.000
# 997        2019-01-23T10:41:54.000
# 998        2019-01-23T21:27:26.000
# 999        2019-01-23T19:12:26.000
#
#                                 resolution_description  road_ramp  status  \
# 0      The Department of Sanitation removed the items.        NaN  Closed
# 1    The Department of Transportation inspected thi...        NaN  Closed
# 2                                                  NaN        NaN  Closed
# 3                                                  NaN        NaN  Closed
# 4    The Department of Sanitation investigated this...        NaN  Closed
# 5                                                  NaN        NaN  Closed
# 6      The Department of Sanitation removed the items.        NaN  Closed
# 7    The Department of Sanitation cleaned the locat...        NaN  Closed
# 8                                                  NaN        NaN  Closed
# 9    The Department of Sanitation investigated this...        NaN  Closed
# 10                                                 NaN        NaN  Closed
# 11                                                 NaN        NaN  Closed
# 12                                                 NaN        NaN  Closed
# 13                                                 NaN        NaN  Closed
# 14                                                 NaN        NaN  Closed
# 15                                                 NaN        NaN  Closed
# 16   The Department of Transportation inspected thi...        NaN  Closed
# 17                                                 NaN        NaN  Closed
# 18                                                 NaN        NaN  Closed
# 19                                                 NaN        NaN  Closed
# 20                                                 NaN        NaN  Closed
# 21                                                 NaN        NaN  Closed
# 22                                                 NaN        NaN  Closed
# 23                                                 NaN        NaN  Closed
# 24                                                 NaN        NaN  Closed
# 25                                                 NaN        NaN  Closed
# 26                                                 NaN        NaN  Closed
# 27                                                 NaN        NaN  Closed
# 28                                                 NaN        NaN  Closed
# 29                                                 NaN        NaN  Closed
# ..                                                 ...        ...     ...
# 970  The Police Department responded and upon arriv...        NaN  Closed
# 971  The Department of Housing Preservation and Dev...        NaN  Closed
# 972  The Police Department responded and upon arriv...        NaN  Closed
# 973  The Police Department issued a summons in resp...        NaN  Closed
# 974  The Department of Housing Preservation and Dev...        NaN  Closed
# 975  The Department of Housing Preservation and Dev...        NaN  Closed
# 976  The Department of Housing Preservation and Dev...        NaN  Closed
# 977  The Police Department issued a summons in resp...        NaN  Closed
# 978  The Department of Sanitation picked up the ite...        NaN  Closed
# 979  The Department of Transportation has completed...        NaN  Closed
# 980  The Department of Housing Preservation and Dev...        NaN  Closed
# 981  The Department of Housing Preservation and Dev...        NaN  Closed
# 982  Service Request status for this request is ava...        NaN  Closed
# 983  The Department of Environmental Protection det...        NaN  Closed
# 984  The Department of Housing Preservation and Dev...        NaN  Closed
# 985  The Department of Housing Preservation and Dev...        NaN  Closed
# 986  The Department of Housing Preservation and Dev...        NaN  Closed
# 987  The Department of Housing Preservation and Dev...        NaN  Closed
# 988                                                NaN        NaN  Closed
# 989  Your Service Request has been submitted to the...        NaN    Open
# 990  The Police Department responded and upon arriv...        NaN  Closed
# 991  Service Request status for this request is ava...        NaN  Closed
# 992                                                NaN        NaN  Closed
# 993  The Department of Housing Preservation and Dev...        NaN  Closed
# 994  The Department of Housing Preservation and Dev...        NaN  Closed
# 995  The Department of Housing Preservation and Dev...        NaN  Closed
# 996  The Department of Housing Preservation and Dev...        NaN  Closed
# 997  The Department of Housing Preservation and Dev...        NaN  Closed
# 998                                         See notes.        NaN  Closed
# 999  The Department of Housing Preservation and Dev...        NaN  Closed
#
#                   street_name  taxi_company_borough  taxi_pick_up_location  \
# 0            EAST    2 STREET                   NaN                    NaN
# 1            EAST   89 STREET                   NaN                    NaN
# 2            WEST   29 STREET                   NaN                    NaN
# 3            LAFAYETTE AVENUE                   NaN                    NaN
# 4                         NaN                   NaN                    NaN
# 5                   41 STREET                   NaN                    NaN
# 6                         NaN                   NaN                    NaN
# 7            EAST  221 STREET                   NaN                    NaN
# 8     THOMAS S BOYLAND STREET                   NaN                    NaN
# 9                         NaN                   NaN                    NaN
# 10           WEST   16 STREET                   NaN                    NaN
# 11           VAN BUREN STREET                   NaN                    NaN
# 12          MONTGOMERY STREET                   NaN                    NaN
# 13               RECTOR PLACE                   NaN                    NaN
# 14           EAST  184 STREET                   NaN                    NaN
# 15                  81 STREET                   NaN                    NaN
# 16                  85 STREET                   NaN                    NaN
# 17            TOMPKINS AVENUE                   NaN                    NaN
# 18            COMMODORE DRIVE                   NaN                    NaN
# 19           EAST   40 STREET                   NaN                    NaN
# 20        CONEY ISLAND AVENUE                   NaN                    NaN
# 21           EAST   17 STREET                   NaN                    NaN
# 22            COLUMBUS AVENUE                   NaN                    NaN
# 23                WARD AVENUE                   NaN                    NaN
# 24                 LENOX ROAD                   NaN                    NaN
# 25                   AVENUE C                   NaN                    NaN
# 26                 189 STREET                   NaN                    NaN
# 27           WEST  190 STREET                   NaN                    NaN
# 28              NELSON AVENUE                   NaN                    NaN
# 29               GATES AVENUE                   NaN                    NaN
# ..                        ...                   ...                    ...
# 970                157 STREET                   NaN                    NaN
# 971             HALSEY STREET                   NaN                    NaN
# 972           WEST 167 STREET                   NaN                    NaN
# 973            WEST 11 STREET                   NaN                    NaN
# 974                 53 AVENUE                   NaN                    NaN
# 975          LEXINGTON AVENUE                   NaN                    NaN
# 976  DR M L KING JR BOULEVARD                   NaN                    NaN
# 977           LABURNAM AVENUE                   NaN                    NaN
# 978            MATILDA AVENUE                   NaN                    NaN
# 979                   61 ROAD                   NaN                    NaN
# 980                102 STREET                   NaN                    NaN
# 981             SEAMAN AVENUE                   NaN                    NaN
# 982                       NaN                   NaN                    NaN
# 983          WEST  126 STREET                   NaN                    NaN
# 984          WILKINSON AVENUE                   NaN                    NaN
# 985          EAST  176 STREET                   NaN                    NaN
# 986              JUDGE STREET                   NaN                    NaN
# 987           ROSEDALE AVENUE                   NaN                    NaN
# 988                167 STREET                   NaN                    NaN
# 989         SAINT MARKS PLACE                   NaN                    NaN
# 990                 42 AVENUE                   NaN                    NaN
# 991                       NaN                   NaN                    NaN
# 992         BEACH   43 STREET                   NaN                    NaN
# 993          WEST  162 STREET                   NaN                    NaN
# 994          LINDEN BOULEVARD                   NaN                    NaN
# 995                   65 ROAD                   NaN                    NaN
# 996          OLINVILLE AVENUE                   NaN                    NaN
# 997           HERKIMER STREET                   NaN                    NaN
# 998           MULBERRY STREET                   NaN                    NaN
# 999           RIVERSIDE DRIVE                   NaN                    NaN
#
#      unique_key  vehicle_type  x_coordinate_state_plane  \
# 0      41329186           NaN                  992860.0
# 1      41330238           NaN                  997582.0
# 984                  249604.0
# 985                  245653.0
# 986                  210691.0
# 987                  236201.0
# 988                  202023.0
# 989                  172392.0
# 990                  211233.0
# 991                  165342.0
# 992                  156695.0
# 993                  244631.0
# 994                  176989.0
# 995                  204939.0
# 996                  259773.0
# 997                  186231.0
# 998                  202137.0
# 999                  244634.0
#
# [1000 rows x 45 columns]

# %%
apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?" \
          "$where=date_extract_y(created_date)=2017" \
          "&$select=count(created_date)"
resp = requests.get(apiURL)
totalRecords = int(resp.text.split('"')[-2])

# Look through column fields to see which data may/not be relevant, get indices.
for idx, col in enumerate(resp_df.columns):
    print(idx, col)
# Out:
# 0 address_type
# 1 agency
# 2 agency_name
# 3 bbl
# 4 borough
# 5 bridge_highway_direction
# 6 bridge_highway_name
# 7 bridge_highway_segment
# 8 city
# 9 closed_date
# 10 community_board
# 11 complaint_type
# 12 created_date
# 13 cross_street_1
# 14 cross_street_2
# 15 descriptor
# 16 due_date
# 17 facility_type
# 18 incident_address
# 19 incident_zip
# 20 intersection_street_1
# 21 intersection_street_2
# 22 landmark
# 23 latitude
# 24 location
# 25 location_address
# 26 location_city
# 27 location_state
# 28 location_type
# 29 location_zip
# 30 longitude
# 31 open_data_channel_type
# 32 park_borough
# 33 park_facility_name
# 34 resolution_action_updated_date
# 35 resolution_description
# 36 road_ramp
# 37 status
# 38 street_name
# 39 taxi_company_borough
# 40 taxi_pick_up_location
# 41 unique_key
# 42 vehicle_type
# 43 x_coordinate_state_plane
# 44 y_coordinate_state_plane

# %%
# My application token. To be removed beforer distribution
headers = {'X-App-Token': 'oKcGXju2HqwSELuW5I9xfRkC0'}

# %% [markdown]
# ### Sources
#
# There are 2 options for obtaining this NYC 311 data:
# 1. Download the full dataset (CSV file)
# 2. Use the Socrata API to query for the data
#
# The full dataset is prohibitively large for my working environment, so I'm choosing the API route. I'm limiting each request to 50,000 records (the max value for v2.0 of this API. I *believe* this endpoint is 2.1 and has no such limit, but I'll keep it to be safe), and will be paging through the data. A count query shows that there are ~2.4M records for 2017, so I'll need to be a little structured about how I make the query.
#
# Most requests finish in a few seconds, but the server seem to does slow down (~30s per request) once I reach about 2M records. This typically finishes in 5 minutes. I currently only kill the process on an unsuccessul response code, but more handling should be implemented for other codes and timeouts. The complete dataframe will get stored to a pickle file to avoid making these API requests for repeated runs.
#
# I initially downloaded the full records so I could have more data to cross-reference for cleaning purposes (i.e. fill in missing zip code and borough fields). Currently when I convert to a dataframe, I throw most of this data away, but this could be used if a more thorough cleaning were undertaken.
#
# Most columns have data of mixed type, so I opted to let Pandas assign a dtype of object/string. I do set the dtype as a string for the zip code since I don't need to do any numeric processing on it and several entries have non-numeric characters.

# %%
def buildNYCData(numRows):
    df_list = list()
    
    numOffset = 0
    count = numRows

    start = time.time()
    apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?" \
             "$where=date_extract_y(created_date)=2017" \
             "&$select=count(created_date)"
    resp = requests.get(apiURL, headers=headers)
    timeElapsed(start)
    print(resp.text.split('"')[-2], 'total records\n')

    while count == numRows:
        apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?" \
                 "$where=date_extract_y(created_date)=2017" \
                 "&$limit=" + str(numRows) + "&$offset=" + str(numOffset)
        
        start = time.time()
        resp = requests.get(apiURL, headers=headers)
        timeElapsed(start)

        print(str(resp.status_code), ': records =', numOffset+numRows)
        if resp.status_code != 200:
            print('API request failed')
            break

        start = time.time()
        csvIO = StringIO(resp.text)
        df_list.append(pd.read_csv(csvIO, dtype={'incident_zip':str},
                       usecols=['borough', 'city', 'complaint_type', 'created_date', 'incident_zip']) \
                               [['created_date', 'complaint_type', 'incident_zip', 'borough', 'city']])
                       #, low_memory=False))# Keeping the warnings

        timeElapsed(start)
        print('\n')
        
        count = df_list[-1].shape[0]
        numOffset += count
        
    return pd.concat(df_list, ignore_index=True)

# %%
numRows = 50000

nyc2_df = buildNYCData(numRows)
# Out:
# 00:00
# 2461208 total records
#
# 00:01
# 200 : records = 50000
# 00:00
#
#
# 00:01
# 200 : records = 100000
# 00:00
#
#
# 00:02
# 200 : records = 150000
# 00:00
#
#
# 00:02
# 200 : records = 200000
# 00:00
#
#
# 00:01
# 200 : records = 250000
# 00:00
#
#
# 00:06
# 200 : records = 300000
# 00:00
#
#
# 00:02
# 200 : records = 350000
# 00:00
#
#
# 00:02
# 200 : records = 400000
# 00:00
#
#
# 00:04
# 200 : records = 450000
# 00:00
#
#
# 00:08
# 200 : records = 500000
# 00:00
#
#
# 00:02
# 200 : records = 550000
# /Users/master/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# 00:00
#
#
# 00:01
# 200 : records = 600000
# 00:00
#
#
# 00:02
# 200 : records = 650000
# 00:00
#
#
# 00:01
# 200 : records = 700000
# 00:00
#
#
# 00:01
# 200 : records = 750000
# 00:00
#
#
# 00:01
# 200 : records = 800000
# 00:00
#
#
# 00:01
# 200 : records = 850000
# 00:00
#
#
# 00:01
# 200 : records = 900000
# 00:00
#
#
# 00:02
# 200 : records = 950000
# 00:00
#
#
# 00:02
# 200 : records = 1000000
# 00:00
#
#
# 00:02
# 200 : records = 1050000
# 00:00
#
#
# 00:01
# 200 : records = 1100000
# 00:00
#
#
# 00:02
# 200 : records = 1150000
# 00:00
#
#
# 00:02
# 200 : records = 1200000
# 00:00
#
#
# 00:02
# 200 : records = 1250000
# 00:00
#
#
# 00:01
# 200 : records = 1300000
# 00:00
#
#
# 00:01
# 200 : records = 1350000
# 00:00
#
#
# 00:02
# 200 : records = 1400000
# 00:00
#
#
# 00:02
# 200 : records = 1450000
# 00:00
#
#
# 00:02
# 200 : records = 1500000
# 00:00
#
#
# 00:02
# 200 : records = 1550000
# 00:00
#
#
# 00:02
# 200 : records = 1600000
# 00:00
#
#
# 00:01
# 200 : records = 1650000
# 00:00
#
#
# 00:02
# 200 : records = 1700000
# 00:00
#
#
# 00:03
# 200 : records = 1750000
# 00:00
#
#
# 00:01
# 200 : records = 1800000
# 00:00
#
#
# 00:01
# 200 : records = 1850000
# 00:00
#
#
# 00:02
# 200 : records = 1900000
# 00:00
#
#
# 00:01
# 200 : records = 1950000
# 00:00
#
#
# 00:03
# 200 : records = 2000000
# 00:00
#
#
# 00:02
# 200 : records = 2050000
# 00:00
#
#
# 00:01
# 200 : records = 2100000
# 00:00
#
#
# 00:01
# 200 : records = 2150000
# 00:00
#
#
# 00:01
# 200 : records = 2200000
# 00:00
#
#
# 00:04
# 200 : records = 2250000
# 00:00
#
#
# 00:02
# 200 : records = 2300000
# 00:00
#
#
# 00:01
# 200 : records = 2350000
# 00:00
#
#
# 00:01
# 200 : records = 2400000
# 00:00
#
#
# 00:01
# 200 : records = 2450000
# 00:00
#
#
# 00:00
# 200 : records = 2500000
# 00:00

# %%
# Store in pickle file locally before cleanup
nyc2_df.to_pickle('nyc2_df.pkl')

# %% [markdown]
#  Now to inspect data and look for missing fields...
#
# ### complaint_type
#
# As seen in the count list below, there are what seems to be duplicates (e.g. `'UNSANITARY CONDITION'` and `'Sanitation condition'`); however, the 311 submission fields online have categories and *subcategories*, many of which seem to change or be user submitted. These records seem to only have the subcategory, and so without context, it's possible I could be mixing complaints from entirely separate categories if I tried any combining.
#
# I will, however, convert these strings to a uniform case to catch any matching categories. This will catch some extra `'PLUMBING'` complaints for example, but it falls outside the top 10.

# %%
nyc2_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# Noise - Residential                    229314
# HEAT/HOT WATER                         210158
# Illegal Parking                        147525
# Blocked Driveway                       137547
# Street Condition                        98622
# UNSANITARY CONDITION                    81801
# Street Light Condition                  81537
# Noise - Street/Sidewalk                 72629
# Water System                            62853
# Noise                                   62191
# PAINT/PLASTER                           59566
# PLUMBING                                50781
# Request Large Bulky Item Collection     49057
# Noise - Commercial                      46997
# Sanitation Condition                    40665
# General Construction/Plumbing           39503
# Missed Collection (All Materials)       37933
# Dirty Conditions                        37446
# Rodent                                  36958
# DOOR/WINDOW                             36347
# Name: complaint_type, dtype: int64

# %%
# Look at count list again after str.upper()
nyc2_df['complaint_type'] = nyc2_df['complaint_type'].str.upper()
nyc2_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# NOISE - RESIDENTIAL                    229314
# HEAT/HOT WATER                         210158
# ILLEGAL PARKING                        147525
# BLOCKED DRIVEWAY                       137547
# STREET CONDITION                        98622
# UNSANITARY CONDITION                    81801
# STREET LIGHT CONDITION                  81537
# NOISE - STREET/SIDEWALK                 72629
# WATER SYSTEM                            62853
# NOISE                                   62191
# PAINT/PLASTER                           59566
# PLUMBING                                56893
# REQUEST LARGE BULKY ITEM COLLECTION     49057
# NOISE - COMMERCIAL                      46997
# SANITATION CONDITION                    40665
# GENERAL CONSTRUCTION/PLUMBING           39503
# MISSED COLLECTION (ALL MATERIALS)       37933
# DIRTY CONDITIONS                        37446
# RODENT                                  36958
# DOOR/WINDOW                             36347
# Name: complaint_type, dtype: int64

# %% [markdown]
# ### borough
#
# There are "unspecified" boroughs that could likely be inferred from **incident_zip**, and that will be done later on with the aid of the NYC borough/zip code database.
#
# Otherwise, there are *many* fields that could be used to fill in the blank (city, cross streets, intersection streets, park borough, etc.). Without more context from NYC 311's info page, it's unclear how to best correlate this data.

# %%
nyc2_df['borough'].value_counts(dropna=False)
# Out:
# BROOKLYN         768828
# QUEENS           593648
# MANHATTAN        481812
# BRONX            455109
# STATEN ISLAND    129194
# Unspecified       32617
# Name: borough, dtype: int64

# %%
bor_missing = len(nyc2_df[nyc2_df['borough'] == 'Unspecified'])
print('{} of {} borough records are missing. This represents {:.3f}% of our data.'
      .format(bor_missing, totalRecords, float(100*bor_missing)/totalRecords))

zip_fix = len(nyc2_df[(nyc2_df['incident_zip'].notna()) & (nyc2_df['borough'] == 'Unspecified')])
print('{} of these {} missing borough entries could be inferred from an available zip code.'
      .format(zip_fix, bor_missing))
print('This could correct up to {:.3f}% of our missing borough data'
      .format(100*float(zip_fix)/bor_missing))
# Out:
# 32617 of 2461208 borough records are missing. This represents 1.325% of our data.
# 3781 of these 32617 missing borough entries could be inferred from an available zip code.
# This could correct up to 11.592% of our missing borough data

# %% [markdown]
# ### incident_zip
#
# There are many missing and irregular entries for this field. I'm not sure there's a clear answer to filling in this data.
#
# Clean up will involve making sure all zip codes are numeric and 5 characters or less.

# %%
nyc2_df['incident_zip'].value_counts(dropna=False)
# Out:
# NaN           96625
# 11226         42438
# 11385         35893
# 10467         34065
# 11207         31436
# 10452         29896
# 10458         29797
# 10453         29571
# 10468         28952
# 11208         28358
# 10456         26918
# 10031         26785
# 10457         26752
# 11221         25900
# 11225         25803
# 11206         25595
# 11213         24633
# 11234         24109
# 10472         23875
# 11212         23765
# 11209         23722
# 11203         23699
# 11233         23441
# 11216         22945
# 10314         22281
# 11215         22076
# 11220         22008
# 11230         21893
# 10032         21641
# 10466         21544
#               ...
# 60604             1
# 10567             1
# 10510             1
# 08063             1
# 43226             1
# 91716-0500        1
# 30006             1
# 07002             1
# 33131             1
# 10159             1
# 10853             1
# 10401             1
# 14901             1
# 11771             1
# 11010             1
# 80235             1
# 07108             1
# 13903             1
# 01234             1
# 05620             1
# 20049             1
# 10514             1
# 28901             1
# 11590             1
# 07111             1
# 43017             1
# 07007             1
# 06831             1
# 30010             1
# 11749             1
# Name: incident_zip, Length: 505, dtype: int64

# %%
zip_missing = len(nyc2_df[nyc2_df['incident_zip'].isna()])
print('{} of {} zip code records are missing. This represents {:.3f}% of our data.'
      .format(zip_missing, totalRecords, float(100*zip_missing)/totalRecords))
# Out:
# 96625 of 2461208 zip code records are missing. This represents 3.926% of our data.

# %% [markdown]
# ## 2010 Census Population Data
#
# This database is available at Splitwise blog and contains US zip codes and population from the 2010 Census.

# %%
censusURL = "https://s3.amazonaws.com/SplitwiseBlogJB/2010+Census+Population+By+Zipcode+(ZCTA).csv"
census_df = pd.read_csv(censusURL, dtype={'Zip Code ZCTA':str})
census_df.head(10)
# Out:
#   Zip Code ZCTA  2010 Census Population
# 0         01001                   16769
# 1         01002                   29049
# 2         01003                   10372
# 3         01005                    5079
# 4         01007                   14649
# 5         01008                    1263
# 6         01009                     741
# 7         01010                    3609
# 8         01011                    1370
# 9         01012                     661

# %%
# Some zip codes are listed twice. Checked all zips that start with '100', '10', '11'. No duplicates.
census_df[census_df['Zip Code ZCTA'].str.startswith('11')]['Zip Code ZCTA'].value_counts();

# %%
# Write to file
census_df.to_pickle('census_df.pkl')

# %% [markdown]
# ## Zip codes for NYC boroughs
#
# This dataset will be needed to match zip codes from the Census dataset with its NYC borough. This is being read from an html table from an NYC enthusiast site. The online formatting will require some transformation here.

# %%
zipsURL = "https://www.nycbynatives.com/nyc_info/new_york_city_zip_codes.php"
zips_df = pd.read_html(zipsURL, match='10001')[0]
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 5 columns
#         0          1   2      3      4
# 0   10001  Manhattan NaN  10451  Bronx
# 1   10002  Manhattan NaN  10452  Bronx
# 2   10003  Manhattan NaN  10453  Bronx
# 3   10004  Manhattan NaN  10454  Bronx
# 4   10005  Manhattan NaN  10455  Bronx
# 5   10006  Manhattan NaN  10456  Bronx
# 6   10007  Manhattan NaN  10457  Bronx
# 7   10009  Manhattan NaN  10458  Bronx
# 8   10010  Manhattan NaN  10459  Bronx
# 9   10011  Manhattan NaN  10460  Bronx
# 10  10012  Manhattan NaN  10461  Bronx
# 11  10013  Manhattan NaN  10462  Bronx
# 12  10014  Manhattan NaN  10463  Bronx
# 13  10015  Manhattan NaN  10464  Bronx
# 14  10016  Manhattan NaN  10465  Bronx
# 15  10017  Manhattan NaN  10466  Bronx
# 16  10018  Manhattan NaN  10467  Bronx
# 17  10019  Manhattan NaN  10468  Bronx
# 18  10020  Manhattan NaN  10469  Bronx
# 19  10021  Manhattan NaN  10470  Bronx

# %%
# The table is displayed twice in different order. Only need one side.
zips_df.drop(labels=[2,3,4], axis='columns', inplace=True)
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 2 columns
#         0          1
# 0   10001  Manhattan
# 1   10002  Manhattan
# 2   10003  Manhattan
# 3   10004  Manhattan
# 4   10005  Manhattan
# 5   10006  Manhattan
# 6   10007  Manhattan
# 7   10009  Manhattan
# 8   10010  Manhattan
# 9   10011  Manhattan
# 10  10012  Manhattan
# 11  10013  Manhattan
# 12  10014  Manhattan
# 13  10015  Manhattan
# 14  10016  Manhattan
# 15  10017  Manhattan
# 16  10018  Manhattan
# 17  10019  Manhattan
# 18  10020  Manhattan
# 19  10021  Manhattan

# %%
# Rename columns and check borough values
zips_df.set_axis(['zip_code', 'borough'], axis='columns', inplace=True)
zips_df['borough'].value_counts()
# Out:
# Manhattan    96
# Queens       63
# Brooklyn     43
# Bronx        25
# Staten       13
# Name: borough, dtype: int64

# %%
# Will convert to uppercase and fix 'Staten' for consistency with previous datasets
zips_df['borough'] = zips_df['borough'].str.upper()
zips_df.loc[zips_df['borough'] == 'STATEN', 'borough'] = 'STATEN ISLAND'

# Convert zip code dtype to string
zips_df['zip_code'] = zips_df['zip_code'].astype(str)

# %%
#  Write to file
zips_df.to_pickle('zips_df.pkl')
