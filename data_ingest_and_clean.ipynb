# %% [markdown]
# # PART 1: SOURCING AND CLEANING DATA
#
# In this notebook, I'll be creating 3 dataframes to analyze 311 complaints in NYC in 2017. The databases are the following:
#
# 1. NYC 311 Service Request Data
# 2. 2010 Census Population Data
# 3. Zip codes for NYC boroughs

# %%
import os
import sys
import time
import requests
import csv

import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

from io import StringIO

# %%
def printTimeElapsed(start):
    elapsed = time.time() - start
    print(time.strftime("%M:%S", time.gmtime(elapsed)))

# %% [markdown]
# ## NYC 311 Service Request Data
# First, I'll take a few probes at the NYC 311 database to see what I'm working with. Much of this has been removed for readability.

# %%
# Get application token from local file, if available

try:
    with open('api_nycOpenData.csv') as f:
        reader = csv.reader(f)
        api_vals = next(reader)
    HEADERS = {api_vals[0] : api_vals[1]}
    print('File found')
    
except:
    print('File not found')
    HEADERS = {}
# Out:
# File found

# %%
pd.set_option('display.max_columns', 30)

api_URL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv"

# Start off with a simple call of 2019 complaints to get a feel for the dataset
PARAMS = {'$where': 'date_extract_y(created_date)=2019'}

resp = requests.get(api_URL, headers=HEADERS, params=PARAMS)
csv_IO = StringIO(resp.text)
resp_df = pd.read_csv(csv_IO)
resp_df
# Out:
#      address_type agency                                        agency_name  \
# 0         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 1         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 2         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 3         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 4         ADDRESS    DOB                            Department of Buildings
# 5         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 6         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 7         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 8         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 9         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 10        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 11        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 12        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 13        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 14        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 15        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 16        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 17        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 18        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 19        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 20        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 21        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 22        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 23        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 24        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 25        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 26        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 27        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 28        ADDRESS    HPD  Department of Housing Preservation and Develop...
# 29        ADDRESS    HPD  Department of Housing Preservation and Develop...
# ..            ...    ...                                                ...
# 970       ADDRESS   DSNY                           Department of Sanitation
# 971       LATLONG    DOT                       Department of Transportation
# 972       ADDRESS    DOF                                 Payment Operations
# 973       ADDRESS   DSNY                                  A - Staten Island
# 974       ADDRESS    DEP             Department of Environmental Protection
# 975       ADDRESS    DEP             Department of Environmental Protection
# 976       ADDRESS    DOF                              External Affairs Unit
# 977       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 978       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 979       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 980       ADDRESS    DEP             Department of Environmental Protection
# 981       ADDRESS    DEP             Department of Environmental Protection
# 982       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 983       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 984       ADDRESS   DSNY                           Department of Sanitation
# 985       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 986       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 987       ADDRESS    DOT                       Department of Transportation
# 988       ADDRESS   NYPD                    New York City Police Department
# 989       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 990       ADDRESS   DSNY                           Department of Sanitation
# 991       ADDRESS    DEP             Department of Environmental Protection
# 992       ADDRESS   DSNY                           Department of Sanitation
# 993       ADDRESS    DOF                                Correspondence Unit
# 994  INTERSECTION    DEP             Department of Environmental Protection
# 995       ADDRESS    DEP             Department of Environmental Protection
# 996       ADDRESS   DSNY                               BCC - Brooklyn North
# 997  INTERSECTION    DEP             Department of Environmental Protection
# 998       ADDRESS   DSNY                           Department of Sanitation
# 999  INTERSECTION   DSNY                               BCC - Brooklyn South
#
#               bbl        borough bridge_highway_direction bridge_highway_name  \
# 0    4.021130e+09         QUEENS                      NaN                 NaN
# 1    3.020070e+09       BROOKLYN                      NaN                 NaN
# 2    3.014060e+09       BROOKLYN                      NaN                 NaN
# 3    3.019570e+09       BROOKLYN                      NaN                 NaN
# 4    2.047640e+09          BRONX                      NaN                 NaN
# 5    1.016220e+09      MANHATTAN                      NaN                 NaN
# 6    1.010410e+09      MANHATTAN                      NaN                 NaN
# 7    4.158100e+09         QUEENS                      NaN                 NaN
# 8    3.012670e+09       BROOKLYN                      NaN                 NaN
# 9    3.008130e+09       BROOKLYN                      NaN                 NaN
# 10   3.016240e+09       BROOKLYN                      NaN                 NaN
# 11   1.021391e+09      MANHATTAN                      NaN                 NaN
# 12   3.069790e+09       BROOKLYN                      NaN                 NaN
# 13   3.009690e+09       BROOKLYN                      NaN                 NaN
# 14   3.013840e+09       BROOKLYN                      NaN                 NaN
# 15   3.013250e+09       BROOKLYN                      NaN                 NaN
# 16   3.050650e+09       BROOKLYN                      NaN                 NaN
# 17   1.015550e+09      MANHATTAN                      NaN                 NaN
# 18   3.062450e+09       BROOKLYN                      NaN                 NaN
# 19   1.014860e+09      MANHATTAN                      NaN                 NaN
# 20   4.131860e+09         QUEENS                      NaN                 NaN
# 21   2.030020e+09          BRONX                      NaN                 NaN
# 22   3.066500e+09       BROOKLYN                      NaN                 NaN
# 23   2.030020e+09          BRONX                      NaN                 NaN
# 24   3.039440e+09       BROOKLYN                      NaN                 NaN
# 25   4.097110e+09         QUEENS                      NaN                 NaN
# 26   2.032940e+09          BRONX                      NaN                 NaN
# 27   2.033240e+09          BRONX                      NaN                 NaN
# 28   1.020700e+09      MANHATTAN                      NaN                 NaN
# 29   2.051410e+09          BRONX                      NaN                 NaN
# ..            ...            ...                      ...                 ...
# 970  4.054200e+09         QUEENS                      NaN                 NaN
# 971           NaN       BROOKLYN                      NaN                 NaN
# 972  3.071320e+09       BROOKLYN                      NaN                 NaN
# 973  5.002170e+09  STATEN ISLAND                      NaN                 NaN
# 974  5.000510e+09  STATEN ISLAND                      NaN                 NaN
# 975  3.079850e+09       BROOKLYN                      NaN                 NaN
# 976  3.009970e+09       BROOKLYN                      NaN                 NaN
# 977  3.010240e+09       BROOKLYN                      NaN                 NaN
# 978  3.039660e+09       BROOKLYN                      NaN                 NaN
# 979  3.005650e+09       BROOKLYN                      NaN                 NaN
# 980  4.136300e+09         QUEENS                      NaN                 NaN
# 981  4.156630e+09         QUEENS                      NaN                 NaN
# 982  2.040210e+09          BRONX                      NaN                 NaN
# 983  3.010080e+09       BROOKLYN                      NaN                 NaN
# 984  3.073070e+09       BROOKLYN                      NaN                 NaN
# 985  4.089430e+09         QUEENS                      NaN                 NaN
# 986  3.074400e+09       BROOKLYN                      NaN                 NaN
# 987  3.000060e+09       BROOKLYN                      NaN                 NaN
# 988  2.057761e+09          BRONX                      NaN                 NaN
# 989  2.037830e+09          BRONX                      NaN                 NaN
# 990  3.052680e+09       BROOKLYN                      NaN                 NaN
# 991  4.008250e+09         QUEENS                      NaN                 NaN
# 992  3.066540e+09       BROOKLYN                      NaN                 NaN
# 993  4.057760e+09         QUEENS                      NaN                 NaN
# 994           NaN      MANHATTAN                      NaN                 NaN
# 995  1.008310e+09      MANHATTAN                      NaN                 NaN
# 996  3.011250e+09       BROOKLYN                      NaN                 NaN
# 997           NaN      MANHATTAN                      NaN                 NaN
# 998  1.005290e+09      MANHATTAN                      NaN                 NaN
# 999           NaN       BROOKLYN                      NaN                 NaN
#
#     bridge_highway_segment                 city              closed_date  \
# 0                      NaN            Rego Park  2019-02-06T21:43:59.000
# 1                      NaN             BROOKLYN  2019-02-06T02:08:59.000
# 2                      NaN             BROOKLYN  2019-02-06T09:19:57.000
# 3                      NaN             BROOKLYN  2019-02-06T02:08:29.000
# 4                      NaN                BRONX  2019-02-08T00:00:00.000
# 5                      NaN             NEW YORK  2019-02-06T07:23:07.000
# 6                      NaN             NEW YORK  2019-02-06T15:46:26.000
# 7                      NaN         Far Rockaway  2019-02-06T21:40:19.000
# 8                      NaN             BROOKLYN  2019-02-06T21:31:35.000
# 997                    NaN             NEW YORK  2019-02-08T05:03:00.000
# 998                    NaN             NEW YORK  2019-02-09T00:00:00.000
# 999                    NaN             BROOKLYN  2019-02-08T12:00:00.000
#
#       community_board                       complaint_type  \
# 0           06 QUEENS                       HEAT/HOT WATER
# 1         02 BROOKLYN                       HEAT/HOT WATER
# 2         09 BROOKLYN                        PAINT/PLASTER
# 3         02 BROOKLYN                       HEAT/HOT WATER
# 4            12 BRONX        General Construction/Plumbing
# 5        11 MANHATTAN                       HEAT/HOT WATER
# 6        04 MANHATTAN                            APPLIANCE
# 7           14 QUEENS                       HEAT/HOT WATER
# 8         09 BROOKLYN                       HEAT/HOT WATER
# 9         07 BROOKLYN                             ELECTRIC
# 10        03 BROOKLYN                       HEAT/HOT WATER
# 11       12 MANHATTAN                             PLUMBING
# 12        13 BROOKLYN                       HEAT/HOT WATER
# 13        06 BROOKLYN                             PLUMBING
# 14        08 BROOKLYN                       HEAT/HOT WATER
# 15        09 BROOKLYN                       HEAT/HOT WATER
# 16        17 BROOKLYN                       HEAT/HOT WATER
# 17       08 MANHATTAN                      FLOORING/STAIRS
# 18        11 BROOKLYN                       HEAT/HOT WATER
# 19       08 MANHATTAN                           WATER LEAK
# 20          13 QUEENS                             PLUMBING
# 21           03 BRONX                       HEAT/HOT WATER
# 22        11 BROOKLYN                       HEAT/HOT WATER
# 23           03 BRONX                       HEAT/HOT WATER
# 24        05 BROOKLYN                       HEAT/HOT WATER
# 25          08 QUEENS                       HEAT/HOT WATER
# 26           07 BRONX                       HEAT/HOT WATER
# 27           07 BRONX                       HEAT/HOT WATER
# 28       09 MANHATTAN                        PAINT/PLASTER
# 29           10 BRONX                       HEAT/HOT WATER
# ..                ...                                  ...
# 970         07 QUEENS  Request Large Bulky Item Collection
# 971       08 BROOKLYN                Street Sign - Damaged
# 972       15 BROOKLYN         DOF Property - Payment Issue
# 973  01 STATEN ISLAND                     Dirty Conditions
# 974  01 STATEN ISLAND                                Noise
# 975       18 BROOKLYN                                Sewer
# 976       06 BROOKLYN         DOF Property - Payment Issue
# 977       06 BROOKLYN                           WATER LEAK
# 978       05 BROOKLYN                            APPLIANCE
# 979       06 BROOKLYN                       HEAT/HOT WATER
# 980         13 QUEENS                                Sewer
# 981         14 QUEENS                                Sewer
# 982          11 BRONX                          DOOR/WINDOW
# 983       06 BROOKLYN                           WATER LEAK
# 984       15 BROOKLYN  Request Large Bulky Item Collection
# 985         09 QUEENS                        PAINT/PLASTER
# 986       15 BROOKLYN                           WATER LEAK
# 987       02 BROOKLYN                Street Sign - Damaged
# 988          08 BRONX                  Noise - Residential
# 989          09 BRONX                        PAINT/PLASTER
# 990       07 BROOKLYN  Request Large Bulky Item Collection
# 991         01 QUEENS                          Air Quality
# 992       11 BROOKLYN  Request Large Bulky Item Collection
# 993         07 QUEENS          DOF Property - Request Copy
# 994      06 MANHATTAN                                Noise
# 995      05 MANHATTAN                                Noise
# 996       08 BROOKLYN                 Sanitation Condition
# 995  2019-02-07T07:33:00.000                     5 AVE
# 996  2019-02-07T10:57:00.000              GRAND AVENUE
# 997  2019-02-07T07:52:00.000                       NaN
# 998  2019-02-07T22:46:00.000          LAFAYETTE STREET
# 999  2019-02-07T13:38:00.000                       NaN
#
#               cross_street_2  ...  longitude open_data_channel_type  \
# 0                        NaN  ... -73.853972                 ONLINE
# 1                        NaN  ... -73.971047                  PHONE
# 2                        NaN  ... -73.937300                  PHONE
# 3                        NaN  ... -73.970678                 MOBILE
# 4                        NaN  ... -73.842767                UNKNOWN
# 5                        NaN  ... -73.943279                  PHONE
# 6                        NaN  ... -73.987809                  PHONE
# 7                        NaN  ... -73.753206                  PHONE
# 8                        NaN  ... -73.954352                 ONLINE
# 9                        NaN  ... -74.017888                  PHONE
# 10                       NaN  ... -73.938004                 ONLINE
# 11                       NaN  ... -73.941228                  PHONE
# 12                       NaN  ... -74.000572                  PHONE
# 13                       NaN  ... -73.982519                  PHONE
# 14                       NaN  ... -73.933072                 ONLINE
# 15                       NaN  ... -73.943110                 ONLINE
# 16                       NaN  ... -73.955004                 ONLINE
# 17                       NaN  ... -73.948798                  PHONE
# 18                       NaN  ... -74.006584                  PHONE
# 19                       NaN  ... -73.952479                  PHONE
# 20                       NaN  ... -73.744247                  PHONE
# 21                       NaN  ... -73.885793                  PHONE
# 22                       NaN  ... -73.979260                  PHONE
# 23                       NaN  ... -73.885793                  PHONE
# 24                       NaN  ... -73.881656                 MOBILE
# 25                       NaN  ... -73.816645                  PHONE
# 26                       NaN  ... -73.892220                  PHONE
# 27                       NaN  ... -73.884939                  PHONE
# 28                       NaN  ... -73.952463                 ONLINE
# 29                       NaN  ... -73.833904                 MOBILE
# ..                       ...  ...        ...                    ...
# 970                45 AVENUE  ... -73.803338                  PHONE
# 971                      NaN  ... -73.928227                 MOBILE
# 972                 AVENUE V  ... -73.965377                  PHONE
# 973                 DEAD END  ... -74.117763                 ONLINE
# 974                     BEND  ... -74.086857                 ONLINE
# 975              GLENWOOD RD  ... -73.914632                  PHONE
# 976                 8 STREET  ... -73.990432                  PHONE
# 977                      NaN  ... -73.984742                  PHONE
# 978                      NaN  ... -73.887153                  PHONE
# 979                      NaN  ... -74.013614                 ONLINE
# 980          HOOK CREEK BLVD  ... -73.727337                  PHONE
# 981                  DIX AVE  ... -73.757345                  PHONE
# 982                      NaN  ... -73.868271                  PHONE
# 983                      NaN  ... -73.992978                  PHONE
# 984                 AVENUE T  ... -73.944401                  PHONE
# 985                      NaN  ... -73.865681                  PHONE
# 986                      NaN  ... -73.949453                 ONLINE
# 987            LITTLE STREET  ... -73.980383                 MOBILE
# 988          WEST 242 STREET  ... -73.898533                 ONLINE
# 989                      NaN  ... -73.870121                  PHONE
# 990  PROSPECT PARK SOUTHWEST  ... -73.973835                  PHONE
# 991                    20 RD  ... -73.904343                  PHONE
# 992            KINGS HIGHWAY  ... -73.975352                  PHONE
# 993                      NaN  ...        NaN                  PHONE
# 981         QUEENS        Unspecified         2019-02-07T13:15:00.000
# 982          BRONX        Unspecified         2019-02-07T08:42:59.000
# 983       BROOKLYN        Unspecified         2019-02-07T10:29:52.000
# 984       BROOKLYN        Unspecified         2019-02-09T00:00:00.000
# 985         QUEENS        Unspecified         2019-02-07T17:20:16.000
# 986       BROOKLYN        Unspecified         2019-02-07T08:43:16.000
# 987       BROOKLYN        Unspecified         2019-02-08T07:27:15.000
# 988          BRONX        Unspecified         2019-02-08T03:17:40.000
# 989          BRONX        Unspecified         2019-02-07T08:42:55.000
# 990       BROOKLYN        Unspecified         2019-02-09T00:00:00.000
# 991         QUEENS        Unspecified         2019-02-08T15:45:00.000
# 992       BROOKLYN        Unspecified         2019-02-09T00:00:00.000
# 993         QUEENS        Unspecified         2019-02-08T10:39:47.000
# 994      MANHATTAN        Unspecified         2019-02-07T11:30:00.000
# 995      MANHATTAN        Unspecified         2019-02-08T05:02:00.000
# 996       BROOKLYN        Unspecified         2019-02-08T12:00:00.000
# 997      MANHATTAN        Unspecified         2019-02-08T05:03:00.000
# 998      MANHATTAN        Unspecified         2019-02-09T00:00:00.000
# 999       BROOKLYN        Unspecified         2019-02-08T12:00:00.000
#
#                                 resolution_description road_ramp    status  \
# 0    The Department of Housing Preservation and Dev...       NaN    Closed
# 1    The Department of Housing Preservation and Dev...       NaN    Closed
# 2    The Department of Housing Preservation and Dev...       NaN    Closed
# 3    The Department of Housing Preservation and Dev...       NaN    Closed
# 4    The Department of Buildings investigated this ...       NaN    Closed
# 5    The Department of Housing Preservation and Dev...       NaN    Closed
# 6    The Department of Housing Preservation and Dev...       NaN    Closed
# 7    The Department of Housing Preservation and Dev...       NaN    Closed
# 8    The Department of Housing Preservation and Dev...       NaN    Closed
# 9    The Department of Housing Preservation and Dev...       NaN    Closed
# 10   The Department of Housing Preservation and Dev...       NaN    Closed
# 11   The Department of Housing Preservation and Dev...       NaN    Closed
# 12   The Department of Housing Preservation and Dev...       NaN    Closed
# 13   The Department of Housing Preservation and Dev...       NaN    Closed
# 14   The Department of Housing Preservation and Dev...       NaN    Closed
# 15   The Department of Housing Preservation and Dev...       NaN    Closed
# 16   The Department of Housing Preservation and Dev...       NaN    Closed
# 17   The Department of Housing Preservation and Dev...       NaN    Closed
# 18   The Department of Housing Preservation and Dev...       NaN    Closed
# 19   The Department of Housing Preservation and Dev...       NaN    Closed
# 20   The Department of Housing Preservation and Dev...       NaN    Closed
# 21   The Department of Housing Preservation and Dev...       NaN    Closed
# 22   The Department of Housing Preservation and Dev...       NaN    Closed
# 23   The Department of Housing Preservation and Dev...       NaN    Closed
# 24   The Department of Housing Preservation and Dev...       NaN    Closed
# 25   The Department of Housing Preservation and Dev...       NaN    Closed
# 26   The Department of Housing Preservation and Dev...       NaN    Closed
# 27   The Department of Housing Preservation and Dev...       NaN    Closed
# 28   The Department of Housing Preservation and Dev...       NaN    Closed
# 29   The Department of Housing Preservation and Dev...       NaN    Closed
# ..                                                 ...       ...       ...
# 970                                                NaN       NaN    Closed
# 971  The Department of Transportation inspected the...       NaN  Assigned
# 972                                         See notes.       NaN    Closed
# 973  The Department of Sanitation investigated this...       NaN    Closed
# 974  The Department of Environmental Protection det...       NaN    Closed
# 975  The Department of Environmental Protection inv...       NaN    Closed
# 976  The Department of Finance received the request...       NaN  Assigned
# 977  The Department of Housing Preservation and Dev...       NaN    Closed
# 978  The Department of Housing Preservation and Dev...       NaN    Closed
# 979  The Department of Housing Preservation and Dev...       NaN    Closed
# 980  The Department of Environmental Protection has...       NaN    Closed
# 981  The Department of Environmental Protection inv...       NaN    Closed
# 982  The Department of Housing Preservation and Dev...       NaN    Closed
# 983  The Department of Housing Preservation and Dev...       NaN    Closed
# 984                                                NaN       NaN    Closed
# 985  The Department of Housing Preservation and Dev...       NaN    Closed
# 986  The Department of Housing Preservation and Dev...       NaN    Closed
# 987  The Department of Transportation inspected the...       NaN    Closed
# 988  The Police Department responded to the complai...       NaN    Closed
# 989  The Department of Housing Preservation and Dev...       NaN    Closed
# 990                                                NaN       NaN    Closed
# 991  The Department of Environmental Protection did...       NaN    Closed
# 992                                                NaN       NaN    Closed
# 993  The Department of Finance mailed the requested...       NaN    Closed
# 994  The Department of Environmental Protection did...       NaN    Closed
# 995  The Department of Environmental Protection req...       NaN    Closed
# 996  The Department of Sanitation investigated this...       NaN    Closed
# 997  The Department of Environmental Protection req...       NaN    Closed
# 998                                                NaN       NaN    Closed
# 999  The location does not meet the criteria for Li...       NaN    Closed
#
#                     street_name taxi_company_borough  taxi_pick_up_location  \
# 0                       64 ROAD                  NaN                    NaN
# 1                CARLTON AVENUE                  NaN                    NaN
# 2              PRESIDENT STREET                  NaN                    NaN
# 3                 GREENE AVENUE                  NaN                    NaN
# 4                 MICKLE AVENUE                  NaN                    NaN
# 5                   PARK AVENUE                  NaN                    NaN
# 6              WEST   50 STREET                  NaN                    NaN
# 7             BEACH   19 STREET                  NaN                    NaN
# 8               EASTERN PARKWAY                  NaN                    NaN
# 9                     53 STREET                  NaN                    NaN
# 10             LEXINGTON AVENUE                  NaN                    NaN
# 11             WEST  177 STREET                  NaN                    NaN
# 12               NEPTUNE AVENUE                  NaN                    NaN
# 13                     5 AVENUE                  NaN                    NaN
# 14               ST JOHNS PLACE                  NaN                    NaN
# 15             EMPIRE BOULEVARD                  NaN                    NaN
# 16              CLARKSON AVENUE                  NaN                    NaN
# 17                     2 AVENUE                  NaN                    NaN
# 18                    78 STREET                  NaN                    NaN
# 19                  YORK AVENUE                  NaN                    NaN
# 20                    230 PLACE                  NaN                    NaN
# 21                BRYANT AVENUE                  NaN                    NaN
# 22             WEST    6 STREET                  NaN                    NaN
# 23                BRYANT AVENUE                  NaN                    NaN
# 24                FULTON STREET                  NaN                    NaN
# 25                     85 DRIVE                  NaN                    NaN
# 26                BRIGGS AVENUE                  NaN                    NaN
# 27   WEST MOSHOLU PARKWAY NORTH                  NaN                    NaN
# 979    41634276           NaN                 980474.0
# 980    41634389           NaN                1059899.0
# 981    41634395           NaN                1051628.0
# 982    41634235           NaN                1020698.0
# 983    41634239           NaN                 986198.0
# 984    41634409           NaN                 999689.0
# 985    41634238           NaN                1021502.0
# 986    41634246           NaN                 998289.0
# 987    41634255           NaN                 989689.0
# 988    41634269           NaN                1012305.0
# 989    41634277           NaN                1020192.0
# 990    41634455           NaN                 991510.0
# 991    41634336           NaN                1010743.0
# 992    41634349           NaN                 991094.0
# 993    41634363           NaN                      NaN
# 994    41634368           NaN                 990178.0
# 995    41634374           NaN                 987642.0
# 996    41634340           NaN                 995312.0
# 997    41634370           NaN                 984621.0
# 998    41634383           NaN                 985994.0
# 999    41634331           NaN                1009256.0
#
#      y_coordinate_state_plane
# 0                    205591.0
# 1                    188524.0
# 2                    182410.0
# 3                    189258.0
# 4                    257091.0
# 5                    230778.0
# 6                    217264.0
# 7                    155721.0
# 8                    183402.0
# 9                    174967.0
# 10                   190360.0
# 11                   248287.0
# 12                   149563.0
# 13                   184734.0
# 14                   183634.0
# 15                   181220.0
# 16                   177957.0
# 17                   224148.0
# 18                   164068.0
# 19                   219292.0
# 20                   182822.0
# 21                   243627.0
# 22                   159978.0
# 23                   243627.0
# 24                   187371.0
# 25                   197569.0
# 26                   254680.0
# 27                   260779.0
# 28                   238740.0
# 29                   257776.0
# ..                        ...
# 970                  215604.0
# 971                  186038.0
# 972                  156869.0
# 973                  169412.0
# 974                  174002.0
# 975                  171692.0
# 976                  184160.0
# 977                  181883.0
# 978                  186049.0
# 979                  186512.0
# 980                  179990.0
# 981                  160277.0
# 982                  246188.0
# 983                  184249.0
# 984                  159102.0
# 985                  189245.0
# 986                  153873.0
# 987                  196044.0
# 988                  263164.0
# 989                  242192.0
# 990                  178104.0
# 991                  222553.0
# 992                  159858.0
# 993                       NaN
# 994                  210722.0
# 995                  210954.0
# 996                  186797.0
# 997                  214435.0
# 998                  203933.0
# 999                  174504.0
#
# [1000 rows x 45 columns]

# %%
# Do a count query to see how many records there are for 2017
PARAMS = {"$where": "date_extract_y(created_date)=2017",
          "$select": "count(created_date)"}
resp = requests.get(api_URL, headers=HEADERS, params=PARAMS)

totalRecords = int(resp.text.split('"')[-2])
print(f"There are {totalRecords} total records for 2017\n")

# Look through column fields to see which data may/not be relevant, get indices.
for idx, col in enumerate(resp_df.columns):
    print(idx, col)
# Out:
# There are 2461208 total records for 2017
#
# 0 address_type
# 1 agency
# 2 agency_name
# 3 bbl
# 4 borough
# 5 bridge_highway_direction
# 6 bridge_highway_name
# 7 bridge_highway_segment
# 8 city
# 9 closed_date
# 10 community_board
# 11 complaint_type
# 12 created_date
# 13 cross_street_1
# 14 cross_street_2
# 15 descriptor
# 16 due_date
# 17 facility_type
# 18 incident_address
# 19 incident_zip
# 20 intersection_street_1
# 21 intersection_street_2
# 22 landmark
# 23 latitude
# 24 location
# 25 location_address
# 26 location_city
# 27 location_state
# 28 location_type
# 29 location_zip
# 30 longitude
# 31 open_data_channel_type
# 32 park_borough
# 33 park_facility_name
# 34 resolution_action_updated_date
# 35 resolution_description
# 36 road_ramp
# 37 status
# 38 street_name
# 39 taxi_company_borough
# 40 taxi_pick_up_location
# 41 unique_key
# 42 vehicle_type
# 43 x_coordinate_state_plane
# 44 y_coordinate_state_plane

# %% [markdown]
# ### Sources
#
# There are 2 options for obtaining this NYC 311 data:
# 1. Download the full dataset (CSV file)
# 2. Use the Socrata API to query for the data
#
# The full dataset is prohibitively large for my working environment, so I'm choosing the API route. I'm limiting each request to 50,000 records (the max value for v2.0 of this API. I *believe* this endpoint is 2.1 and has no such limit, but I'll keep it to be safe), and will be paging through the data. A count query shows that there are ~2.4M records for 2017, so I'll need to be a little structured about how I make the query.
#
# Most requests finish in a few seconds, but the server seem to does slow down (~30s per request) every so often. Otherwise, this process typically takes about 5 minutes. I currently only kill the process on an unsuccessul response code, but more handling should be implemented for other codes and timeouts. The complete dataframe will get stored to a pickle file to avoid making these API requests for repeated runs.
#
# I initially downloaded the full records so I could have more data to cross-reference for cleaning purposes (i.e. fill in missing zip code and borough fields). Currently when I convert to a dataframe, I throw most of this data away, but this could be used if a more thorough cleaning were undertaken.
#
# Most columns have data of mixed type, so I opted to let Pandas assign a dtype of object/string. I do set the dtype as a string for the zip code since I don't need to do any numeric processing on it and several entries have non-numeric characters.

# %%
def buildNYCData(num_rows):
    df_list = list()
    
    num_offset = 0
    count = num_rows
    
    while count == num_rows:
        PARAMS = {"$where": "date_extract_y(created_date)=2017",
                  "$order": ":id", # Use Socrata default ordering for paging
                  "$limit": str(num_rows),
                  "$offset": str(num_offset)}

        start = time.time()
        resp = requests.get(api_URL, headers=HEADERS, params=PARAMS)
        printTimeElapsed(start)
        
        print("API Response: {}".format(resp.status_code))
        if resp.status_code != 200:
            print('API request failed')
            break

        start = time.time()
        csv_IO = StringIO(resp.text)
        df_list.append(pd.read_csv(csv_IO, dtype={'incident_zip': str},
                       usecols=['borough', 'city', 'complaint_type', 'created_date', 'incident_zip']) \
                               [['created_date', 'complaint_type', 'incident_zip', 'borough', 'city']])
                       #, low_memory=False))# Keeping the warnings

        count = df_list[-1].shape[0]
        num_offset += count
        printTimeElapsed(start)
        
        print('Records = {}\n'.format(num_offset))
        
    return pd.concat(df_list, ignore_index=True)

# %%
num_rows = 50000

# Don't query the data for repeated runs
if os.path.isfile('nyc1_df.pkl'):
    nyc1_df = pd.read_pickle('nyc1_df.pkl')
else:
    nyc1_df = buildNYCData(num_rows)
# Out:
# 00:01
# API Response: 200
# 00:00
# Records = 50000
#
# 00:01
# API Response: 200
# 00:00
# Records = 100000
#
# 00:02
# API Response: 200
# 00:00
# Records = 150000
#
# 00:02
# API Response: 200
# 00:00
# Records = 200000
#
# 00:04
# API Response: 200
# 00:00
# Records = 250000
#
# 00:02
# API Response: 200
# 00:00
# Records = 300000
#
# 00:05
# API Response: 200
# 00:00
# Records = 350000
#
# 00:01
# API Response: 200
# 00:00
# Records = 400000
#
# 00:33
# API Response: 200
# 00:00
# Records = 450000
#
# 00:34
# API Response: 200
# 00:00
# Records = 500000
#
# 00:34
# API Response: 200
# 00:00
# Records = 550000
#
# 00:36
# API Response: 200
# 00:00
# Records = 600000
#
# 00:37
# API Response: 200
# 00:00
# Records = 650000
#
# 00:34
# API Response: 200
# 00:00
# Records = 700000
#
# 00:39
# API Response: 200
# 00:00
# Records = 750000
#
# 00:36
# API Response: 200
# 00:00
# Records = 800000
#
# 00:37
# API Response: 200
# 00:00
# Records = 850000
#
# 00:36
# API Response: 200
# 00:00
# Records = 900000
#
# 00:38
# API Response: 200
# 00:00
# Records = 950000
#
# 00:40
# API Response: 200
# 00:00
# Records = 1000000
#
# 00:38
# API Response: 200
# 00:00
# Records = 1050000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1100000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1150000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1200000
#
# 00:38
# API Response: 200
# 00:00
# Records = 1250000
#
# 00:34
# API Response: 200
# 00:00
# Records = 1300000
#
# 00:38
# API Response: 200
# 00:00
# Records = 1350000
#
# 00:36
# API Response: 200
# 00:00
# Records = 1400000
#
# 00:37
# API Response: 200
# 00:00
# Records = 1450000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1500000
#
# 00:36
# API Response: 200
# 00:00
# Records = 1550000
#
# 00:37
# API Response: 200
# 00:00
# Records = 1600000
#
# 00:36
# API Response: 200
# 00:00
# Records = 1650000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1700000
#
# 00:39
# API Response: 200
# 00:00
# Records = 1750000
#
# 00:45
# API Response: 200
# 00:00
# Records = 1800000
#
# 00:35
# API Response: 200
# 00:00
# Records = 1850000
#
# 00:36
# API Response: 200
# 00:00
# Records = 1900000
#
# 00:34
# API Response: 200
# 00:00
# Records = 1950000
#
# 00:40
# API Response: 200
# 00:00
# Records = 2000000
#
# 00:52
# API Response: 200
# 00:00
# Records = 2050000
#
# 00:44
# API Response: 200
# 00:00
# Records = 2100000
#
# 00:37
# API Response: 200
# 00:00
# Records = 2150000
#
# 00:42
# API Response: 200
# 00:00
# Records = 2200000
#
# 00:54
# API Response: 200
# 00:00
# Records = 2250000
#
# 00:38
# API Response: 200
# 00:00
# Records = 2300000
#
# 00:43
# API Response: 200
# 00:00
# Records = 2350000
#
# 00:38
# API Response: 200
# 00:00
# Records = 2400000
#
# 00:35
# API Response: 200
# /Users/master/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# 00:00
# Records = 2450000
#
# 00:38
# API Response: 200
# 00:00
# Records = 2461208

# %%
# Store in pickle file locally before cleanup
nyc1_df.to_pickle('nyc1_df.pkl')

# %% [markdown]
#  Now to inspect data and look for missing fields...
#
# ### complaint_type
#
# As seen in the count list below, there are what seems to be duplicates (e.g. `'UNSANITARY CONDITION'` and `'Sanitation condition'`); however, the 311 submission fields online have categories and *subcategories*, many of which seem to change or be user submitted. These records seem to only have the subcategory, and so without context, it's possible I could be mixing complaints from entirely separate categories if I tried any combining.
#
# I will, however, convert these strings to a uniform case to catch any matching categories. This will catch some extra `'PLUMBING'` complaints for example, but it falls outside the top 10.

# %%
nyc1_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# Noise - Residential                    230152
# HEAT/HOT WATER                         213521
# Illegal Parking                        146122
# Blocked Driveway                       136097
# Street Condition                        93265
# Street Light Condition                  84195
# UNSANITARY CONDITION                    79282
# Noise - Street/Sidewalk                 73085
# Water System                            65100
# Noise                                   60171
# PAINT/PLASTER                           57076
# PLUMBING                                49969
# Noise - Commercial                      47394
# Request Large Bulky Item Collection     46614
# General Construction/Plumbing           43013
# Sanitation Condition                    38937
# Missed Collection (All Materials)       36260
# Traffic Signal Condition                36178
# Dirty Conditions                        35887
# Rodent                                  35075
# Name: complaint_type, dtype: int64

# %%
# Look at count list again after str.upper()
nyc1_df['complaint_type'] = nyc1_df['complaint_type'].str.upper()
nyc1_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# NOISE - RESIDENTIAL                    230152
# HEAT/HOT WATER                         213521
# ILLEGAL PARKING                        146122
# BLOCKED DRIVEWAY                       136097
# STREET CONDITION                        93265
# STREET LIGHT CONDITION                  84195
# UNSANITARY CONDITION                    79282
# NOISE - STREET/SIDEWALK                 73085
# WATER SYSTEM                            65100
# NOISE                                   60171
# PAINT/PLASTER                           57076
# PLUMBING                                56367
# NOISE - COMMERCIAL                      47394
# REQUEST LARGE BULKY ITEM COLLECTION     46614
# GENERAL CONSTRUCTION/PLUMBING           43013
# SANITATION CONDITION                    38937
# MISSED COLLECTION (ALL MATERIALS)       36260
# TRAFFIC SIGNAL CONDITION                36178
# DIRTY CONDITIONS                        35887
# RODENT                                  35075
# Name: complaint_type, dtype: int64

# %% [markdown]
# ### borough
#
# There are "unspecified" boroughs that could likely be inferred from **incident_zip**, and that will be done later on with the aid of the NYC borough/zip code database.
#
# Otherwise, there are *many* fields that could be used to fill in the blank (city, cross streets, intersection streets, park borough, etc.). Without more context from NYC 311's info page, it's unclear how to best correlate this data.

# %%
nyc1_df['borough'].value_counts(dropna=False)
# Out:
# BROOKLYN         771324
# QUEENS           589983
# MANHATTAN        480351
# BRONX            450933
# STATEN ISLAND    127141
# Unspecified       41476
# Name: borough, dtype: int64

# %%
bor_missing = len(nyc1_df[nyc1_df['borough'] == 'Unspecified'])
print('{} of {} borough records are missing. This represents {:.3f}% of our data.'
      .format(bor_missing, totalRecords, float(100*bor_missing)/totalRecords))

zc_without_bor = len(nyc1_df[(nyc1_df['incident_zip'].notna()) & (nyc1_df['borough'] == 'Unspecified')])
print('{} of these {} missing borough entries could be inferred from an available zip code.'
      .format(zc_without_bor, bor_missing))
print('This could correct up to {:.3f}% of our missing borough data'
      .format(100*float(zc_without_bor)/bor_missing))
# Out:
# 41476 of 2461208 borough records are missing. This represents 1.685% of our data.
# 4440 of these 41476 missing borough entries could be inferred from an available zip code.
# This could correct up to 10.705% of our missing borough data

# %% [markdown]
# ### incident_zip
#
# There are many missing and irregular entries for this field. I'm not sure there's a clear answer to filling in this data.
#
# Clean up will involve making sure all zip codes are numeric and 5 characters or less.

# %%
nyc1_df['incident_zip'].value_counts(dropna=False)
# Out:
# NaN           117792
# 11226          42131
# 11385          35089
# 10467          34086
# 11207          30779
# 10453          29706
# 10458          28942
# 10452          28545
# 10468          28525
# 11208          28394
# 11221          26301
# 10456          26214
# 10457          25979
# 10031          25836
# 11206          25112
# 11209          24842
# 11225          24833
# 11234          24394
# 11213          24316
# 11233          23652
# 11203          23409
# 10472          23407
# 11212          23347
# 11216          23238
# 11230          21830
# 11220          21711
# 10314          21710
# 11215          21604
# 11238          21371
# 10032          20982
#                ...
# 11771              1
# 98036              1
# 31600              1
# 34134              1
# 43226              1
# 60179              1
# 08063              1
# 19007              1
# 110044             1
# 01583              1
# 10538              1
# 06840              1
# 12525              1
# 10426              1
# 89117              1
# 11735-9100         1
# 13202              1
# 10590              1
# 14624              1
# 10008              1
# 12250              1
# 92675              1
# 32780              1
# 30022              1
# 95035              1
# 92131              1
# 92108              1
# 10606              1
# 48071              1
# 07103              1
# Name: incident_zip, Length: 679, dtype: int64

# %%
zip_missing = len(nyc1_df[nyc1_df['incident_zip'].isna()])
print('{} of {} zip code records are missing. This represents {:.3f}% of our data.'
      .format(zip_missing, totalRecords, float(100*zip_missing)/totalRecords))
# Out:
# 117792 of 2461208 zip code records are missing. This represents 4.786% of our data.

# %% [markdown]
# There are several ways zip codes fields can be corrupted:
# - 4 digit specifier may be appended (e.g. 10001-1234)
# - Too short, too long
# - Non-numeric characters
#
# I'll fix some of these and set the rest to np.nan

# %%
# View all entries with dashed zip codes
nyc1_df[nyc1_df['incident_zip'].str.contains('-', na=False)]
# Out:
#                     created_date      complaint_type incident_zip  \
# 13711    2017-01-03T12:24:17.000  CONSUMER COMPLAINT   90054-0807
# 151419   2017-01-24T16:52:07.000  CONSUMER COMPLAINT   11802-9060
# 279796   2017-02-13T06:29:56.000         TAXI REPORT   11973-5000
# 286215   2017-02-14T17:07:34.000  CONSUMER COMPLAINT   02298-1002
# 336941   2017-02-21T15:36:34.000  CONSUMER COMPLAINT   07660-2112
# 378836   2017-03-01T12:51:01.000  CONSUMER COMPLAINT   12550-0831
# 423811   2017-03-08T15:48:57.000  CONSUMER COMPLAINT   85285-7288
# 547246   2017-03-28T09:05:55.000  CONSUMER COMPLAINT   19714-7526
# 556493   2017-03-23T18:13:20.000  CONSUMER COMPLAINT   11802-9060
# 639800   2017-04-13T16:14:28.000  CONSUMER COMPLAINT   32255-1268
# 700804   2017-04-20T12:25:07.000  CONSUMER COMPLAINT   11766-0402
# 745378   2017-04-25T14:51:15.000  CONSUMER COMPLAINT   32255-1268
# 785039   2017-05-05T10:46:40.000  CONSUMER COMPLAINT   48333-9223
# 863632   2017-05-15T16:55:15.000  CONSUMER COMPLAINT   60675-1738
# 904872   2017-05-21T17:45:40.000  CONSUMER COMPLAINT   40290-1037
# 930469   2017-05-25T16:17:37.000  CONSUMER COMPLAINT   92571-0801
# 931779   2017-05-25T11:04:59.000  CONSUMER COMPLAINT   29615-5720
# 979933   2017-06-02T09:23:18.000  CONSUMER COMPLAINT   11735-9100
# 1004459  2017-06-05T20:07:10.000  CONSUMER COMPLAINT   55433-5876
# 1041516  2017-06-11T07:53:15.000  CONSUMER COMPLAINT   12207-2543
# 1124640  2017-06-22T16:45:05.000  CONSUMER COMPLAINT   11757-0602
# 1128064  2017-06-23T16:51:47.000  CONSUMER COMPLAINT   63179-0441
# 1168929  2017-06-29T14:39:05.000  CONSUMER COMPLAINT   43218-2273
# 1497471  2017-08-18T15:04:48.000  CONSUMER COMPLAINT   68501-2505
# 1718205  2017-09-21T12:03:59.000  CONSUMER COMPLAINT   43218-3003
# 1751234  2017-09-25T13:15:46.000               SCRIE   11357-1656
# 1772905  2017-09-28T15:04:32.000  CONSUMER COMPLAINT   02061-1674
# 2011243  2017-11-02T14:08:30.000  CONSUMER COMPLAINT   11772-3518
# 2169238  2017-11-24T12:30:11.000     HOUSING OPTIONS   19139-1258
# 2249288  2017-12-06T15:27:15.000  CONSUMER COMPLAINT   91716-0500
# 2400526  2017-12-28T14:25:17.000  CONSUMER COMPLAINT   37214-0065
#
#              borough              city
# 13711    Unspecified      LOS ANGELOUS
# 151419   Unspecified        HICKSVILLE
# 279796   Unspecified          NEW YORK
# 286215   Unspecified            BOSTON
# 336941   Unspecified   RIDGEFIELD PARK
# 378836   Unspecified          NEWBURGH
# 423811   Unspecified             TEMPE
# 547246   Unspecified            NEWARK
# 556493   Unspecified        HICKSVILLE
# 639800   Unspecified      JACKSONVILLE
# 700804   Unspecified          MT SINAI
# 745378   Unspecified      JACKSONVILLE
# 785039   Unspecified  FARMINGTON HILLS
# 863632   Unspecified           CHICAGO
# 904872   Unspecified        LOUISVILLE
# 930469   Unspecified            PERRIS
# 931779   Unspecified        GREENVILLE
# 979933   Unspecified       FARMINGDALE
# 1004459  Unspecified       COON RAPIDS
# 1041516  Unspecified            ALBANY
# 1124640  Unspecified       LINDENHURST
# 1128064  Unspecified       SAINT LOUIS
# 1168929  Unspecified          COLUMBUS
# 1497471  Unspecified           LINCOLN
# 1718205  Unspecified          COLUMBUS
# 1751234  Unspecified        WHITESTONE
# 1772905  Unspecified           NORWELL
# 2011243  Unspecified         PATCHOGUE
# 2169238  Unspecified      PHILADELPHIA
# 2249288  Unspecified  CITY OF INDUSTRY
# 2400526  Unspecified         NASHVILLE

# %% [markdown]
# This section will iterate through the zip code column looking for a '-'. If found, then the first 5 digits will preserved.

# %%
for idx, val in enumerate(nyc1_df['incident_zip']):
    if '-' in str(val):
        #print(val.split('-'))
        nyc1_df.loc[idx, 'incident_zip'] = val.split('-')[0]

# %% [markdown]
# Manually iterate again looking for strings that likely can't have a useful zip code extracted. Any entries that have non-numeric characters or are of the wrong length will be removed (i.e. NaN).

# %%
bad_val_count = 0
for idx, val in enumerate(nyc1_df['incident_zip']):
    if str(val) == 'nan':
        continue
    elif not str(val).isnumeric():
        bad_val_count += 1
        nyc1_df.loc[idx, 'incident_zip'] = np.nan
    elif len(str(val)) != 5:
        bad_val_count += 1
        nyc1_df.loc[idx, 'incident_zip'] = np.nan
        
print(f'{bad_val_count} values were identified')
# Out:
# 60 values were identified

# %% [markdown]
# ## 2010 Census Population Data
#
# This database is available at Splitwise blog and contains US zip codes and population from the 2010 Census.

# %%
census_URL = "https://s3.amazonaws.com/SplitwiseBlogJB/2010+Census+Population+By+Zipcode+(ZCTA).csv"
census_df = pd.read_csv(census_URL, dtype={'Zip Code ZCTA': str})
census_df.head(10)
# Out:
#   Zip Code ZCTA  2010 Census Population
# 0         01001                   16769
# 1         01002                   29049
# 2         01003                   10372
# 3         01005                    5079
# 4         01007                   14649
# 5         01008                    1263
# 6         01009                     741
# 7         01010                    3609
# 8         01011                    1370
# 9         01012                     661

# %%
# Some zip codes are listed twice. Checked all zips that start with '100', '10', '11'. No duplicates.
census_df[census_df['Zip Code ZCTA'].str.startswith('11')]['Zip Code ZCTA'].value_counts();

# %%
# Write to file
census_df.to_pickle('census_df.pkl')

# %% [markdown]
# ## Zip codes for NYC boroughs
#
# This dataset will be needed to match zip codes from the Census dataset with its NYC borough. This is being read from an html table from an NYC enthusiast site. The online formatting will require some transformation here.

# %%
zips_URL = "https://www.nycbynatives.com/nyc_info/new_york_city_zip_codes.php"
zips_df = pd.read_html(zips_URL, match='10001')[0]
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 5 columns
#         0          1   2      3      4
# 0   10001  Manhattan NaN  10451  Bronx
# 1   10002  Manhattan NaN  10452  Bronx
# 2   10003  Manhattan NaN  10453  Bronx
# 3   10004  Manhattan NaN  10454  Bronx
# 4   10005  Manhattan NaN  10455  Bronx
# 5   10006  Manhattan NaN  10456  Bronx
# 6   10007  Manhattan NaN  10457  Bronx
# 7   10009  Manhattan NaN  10458  Bronx
# 8   10010  Manhattan NaN  10459  Bronx
# 9   10011  Manhattan NaN  10460  Bronx
# 10  10012  Manhattan NaN  10461  Bronx
# 11  10013  Manhattan NaN  10462  Bronx
# 12  10014  Manhattan NaN  10463  Bronx
# 13  10015  Manhattan NaN  10464  Bronx
# 14  10016  Manhattan NaN  10465  Bronx
# 15  10017  Manhattan NaN  10466  Bronx
# 16  10018  Manhattan NaN  10467  Bronx
# 17  10019  Manhattan NaN  10468  Bronx
# 18  10020  Manhattan NaN  10469  Bronx
# 19  10021  Manhattan NaN  10470  Bronx

# %%
# The table is displayed twice in different order. Only need one side.
zips_df.drop(labels=[2,3,4], axis='columns', inplace=True)
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 2 columns
#         0          1
# 0   10001  Manhattan
# 1   10002  Manhattan
# 2   10003  Manhattan
# 3   10004  Manhattan
# 4   10005  Manhattan
# 5   10006  Manhattan
# 6   10007  Manhattan
# 7   10009  Manhattan
# 8   10010  Manhattan
# 9   10011  Manhattan
# 10  10012  Manhattan
# 11  10013  Manhattan
# 12  10014  Manhattan
# 13  10015  Manhattan
# 14  10016  Manhattan
# 15  10017  Manhattan
# 16  10018  Manhattan
# 17  10019  Manhattan
# 18  10020  Manhattan
# 19  10021  Manhattan

# %%
# Rename columns and check borough values
zips_df.set_axis(['zip_code', 'borough'], axis='columns', inplace=True)
zips_df['borough'].value_counts()
# Out:
# Manhattan    96
# Queens       63
# Brooklyn     43
# Bronx        25
# Staten       13
# Name: borough, dtype: int64

# %%
# Will convert to uppercase and fix 'Staten' for consistency with previous datasets
zips_df['borough'] = zips_df['borough'].str.upper()
zips_df.loc[zips_df['borough'] == 'STATEN', 'borough'] = 'STATEN ISLAND'

# Convert zip code dtype to string
zips_df['zip_code'] = zips_df['zip_code'].astype(str)

# %%
#  Write to file
zips_df.to_pickle('zips_df.pkl')

# %% [markdown]
# ## Revisit 311 NYC Data for cross correlation
#
# Some records in the 311 NYC database have a zip code but an 'Unspecified' borough. These zip codes can easily be used to find the matching borough using the previous dataset (zip codes for NYC boroughs). This will be done by merging the two databases and reassigning *only* the 'Unspecified' fields if there is a zip code match.
#
# Another option, which I also tried out (not shown), is to assume the NYC 311 zip code field *takes precedence* over the borough if there is a mismatch. In this case, I found that several boroughs were overreported, namely Bronx and Manhattan. This may be a valid option, but I'll opt to preserve the original database values for this project.

# %%
# Temporarily rename column so there is no conflict in the merge
zips_df = zips_df.rename(columns={'borough': 'nycborough'})

m_df = nyc1_df.merge(zips_df, left_on='incident_zip', right_on='zip_code', how='left')

m_df.loc[(m_df['incident_zip'] == m_df['zip_code']) & \
         (m_df['borough'] == 'Unspecified'), 'borough'] = m_df['nycborough']

del m_df['zip_code']
del m_df['nycborough']

print('BEFORE')
print(nyc1_df['borough'].value_counts(), '\n')

print('AFTER')
print(m_df['borough'].value_counts(), '\n')


print("The original data had {} missing borough fields, {} of which had an accompanying zip code."
      .format(bor_missing, zc_without_bor))

final_bor_missing = len(m_df[m_df['borough'] == 'Unspecified'])
print("The corrected data has {} missing borough fields, an improvement of {} fields."
      .format(final_bor_missing, bor_missing-final_bor_missing))

nyc1_df = m_df
# Out:
# BEFORE
# BROOKLYN         771324
# QUEENS           589983
# MANHATTAN        480351
# BRONX            450933
# STATEN ISLAND    127141
# Unspecified       41476
# Name: borough, dtype: int64
#
# AFTER
# BROOKLYN         771659
# QUEENS           590318
# MANHATTAN        480606
# BRONX            451039
# STATEN ISLAND    129485
# Unspecified       38101
# Name: borough, dtype: int64
#
# The original data had 41476 missing borough fields, 4440 of which had an accompanying zip code.
# The corrected data has 38101 missing borough fields, an improvement of 3375 fields.

# %%
# Write cleaned up NYC dataframe to separate file 
nyc1_df.to_pickle('nyc2_df.pkl')
