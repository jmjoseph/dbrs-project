# %% [markdown]
# # PART 1: SOURCING AND CLEANING DATA
#
# In this notebook, I'll be creating 3 dataframes to analyze 311 complaints in NYC in 2017. The databases are the following:
#
# 1. NYC 311 Service Request Data
# 2. 2010 Census Population Data
# 3. Zip codes for NYC boroughs

# %%
import os
import sys
import time
import requests
import csv

import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

from io import StringIO

# %%
def timeElapsed(start):
    elapsed = time.time() - start
    print(time.strftime("%M:%S", time.gmtime(elapsed)))

# %% [markdown]
# ## NYC 311 Service Request Data
# First, I'll take a few probes at the NYC 311 database to see what I'm working with. Much of this has been removed for readability.

# %%
# Get application token from local file, if available

try:
    with open('api_nycOpenData.csv') as f:
        reader = csv.reader(f)
        api_vals = next(reader)
    HEADERS = {api_vals[0] : api_vals[1]}
    
except:
    print('File not found')
    HEADERS = {}
    
print(HEADERS)
# Out:
# {'X-App-Token': 'oKcGXju2HqwSELuW5I9xfRkC0'}

# %%
pd.set_option('display.max_columns', 60)

# Start off with a simple call of 2019 complaints to get a feel for the dataset
apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?$where=date_extract_y(created_date)=2019"

resp = requests.get(apiURL, headers=HEADERS)
csvIO = StringIO(resp.text)
resp_df = pd.read_csv(csvIO)
resp_df
# Out:
#      address_type agency                                        agency_name  \
# 0             NaN   DCAS                                               DCAS
# 1         ADDRESS    DEP             Department of Environmental Protection
# 2         ADDRESS    DOF                                 Condo or CoOp Unit
# 3         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 4         ADDRESS   DSNY                               BCC - Brooklyn South
# 5         ADDRESS   DSNY                               BCC - Brooklyn North
# 6         ADDRESS   DSNY                                           Bronx 04
# 7         ADDRESS   DSNY                           Department of Sanitation
# 8         ADDRESS    DOT                       Department of Transportation
# 9         ADDRESS    HPD  Department of Housing Preservation and Develop...
# 10   INTERSECTION    DOT                       Department of Transportation
# 11   INTERSECTION    DEP             Department of Environmental Protection
# 12        ADDRESS   DSNY                           Department of Sanitation
# 13        ADDRESS    DOT                       Department of Transportation
# 14        ADDRESS   NYPD                    New York City Police Department
# 15        ADDRESS   NYPD                    New York City Police Department
# 16        ADDRESS   NYPD                    New York City Police Department
# 17        ADDRESS    DOT                       Department of Transportation
# 18        ADDRESS    DEP             Department of Environmental Protection
# 19        ADDRESS    DEP             Department of Environmental Protection
# 20        ADDRESS   DSNY                           Department of Sanitation
# 21        ADDRESS    DEP             Department of Environmental Protection
# 22   INTERSECTION    DEP             Department of Environmental Protection
# 23        ADDRESS    DEP             Department of Environmental Protection
# 24        ADDRESS    DOB                            Department of Buildings
# 25        ADDRESS    DOF                                       Land Records
# 26   INTERSECTION   DSNY                               BCC - Brooklyn North
# 27        ADDRESS  DOHMH            Department of Health and Mental Hygiene
# 28        ADDRESS   NYPD                    New York City Police Department
# 29        ADDRESS   DSNY                                       Manhattan 04
# ..            ...    ...                                                ...
# 970       ADDRESS   NYPD                    New York City Police Department
# 971       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 972       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 973       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 974  INTERSECTION   NYPD                    New York City Police Department
# 975       ADDRESS   DSNY                                     Queens East 10
# 976       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 977       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 978       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 979       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 980       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 981       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 982       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 983       ADDRESS   DSNY                               BCC - Brooklyn South
# 984  INTERSECTION   NYPD                    New York City Police Department
# 985       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 986       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 987       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 988       ADDRESS   NYPD                    New York City Police Department
# 989       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 990       ADDRESS   NYPD                    New York City Police Department
# 991       ADDRESS   NYPD                    New York City Police Department
# 992       ADDRESS   NYPD                    New York City Police Department
# 993       ADDRESS   DSNY                           Department of Sanitation
# 994  INTERSECTION    DOT                       Department of Transportation
# 995       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 996       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 997       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 998       ADDRESS    HPD  Department of Housing Preservation and Develop...
# 999       ADDRESS    DOB                            Department of Buildings
#
#               bbl        borough  bridge_highway_direction  \
# 0             NaN    Unspecified                       NaN
# 1    3.060850e+09       BROOKLYN                       NaN
# 2    1.011668e+09      MANHATTAN                       NaN
# 3    3.012610e+09       BROOKLYN                       NaN
# 4    3.068290e+09       BROOKLYN                       NaN
# 5    3.033400e+09       BROOKLYN                       NaN
# 6    2.025260e+09          BRONX                       NaN
# 7             NaN      MANHATTAN                       NaN
# 8    4.139120e+09         QUEENS                       NaN
# 9    2.023980e+09          BRONX                       NaN
# 10            NaN      MANHATTAN                       NaN
# 11            NaN      MANHATTAN                       NaN
# 12   1.004080e+09      MANHATTAN                       NaN
# 13   4.133580e+09         QUEENS                       NaN
# 14   5.010890e+09  STATEN ISLAND                       NaN
# 15   5.011210e+09  STATEN ISLAND                       NaN
# 16   4.068290e+09         QUEENS                       NaN
# 17            NaN  STATEN ISLAND                       NaN
# 18   1.016870e+09      MANHATTAN                       NaN
# 19   1.011490e+09      MANHATTAN                       NaN
# 20   3.015160e+09       BROOKLYN                       NaN
# 21   3.035080e+09       BROOKLYN                       NaN
# 22            NaN       BROOKLYN                       NaN
# 23   1.008840e+09      MANHATTAN                       NaN
# 24   4.141520e+09         QUEENS                       NaN
# 25   5.036890e+09  STATEN ISLAND                       NaN
# 26            NaN       BROOKLYN                       NaN
# 27   2.023700e+09          BRONX                       NaN
# 28   4.036240e+09         QUEENS                       NaN
# 29   1.010590e+09      MANHATTAN                       NaN
# ..            ...            ...                       ...
# 970  1.016780e+09      MANHATTAN                       NaN
# 971  2.027470e+09          BRONX                       NaN
# 972  2.028290e+09          BRONX                       NaN
# 973  1.022280e+09      MANHATTAN                       NaN
# 974           NaN      MANHATTAN                       NaN
# 975  4.117710e+09         QUEENS                       NaN
# 976  3.048030e+09       BROOKLYN                       NaN
# 977  2.048470e+09          BRONX                       NaN
# 978  2.028350e+09          BRONX                       NaN
# 979  2.024590e+09          BRONX                       NaN
# 980  2.050670e+09          BRONX                       NaN
# 981  2.027840e+09          BRONX                       NaN
# 982  2.031780e+09          BRONX                       NaN
# 983  3.074420e+09       BROOKLYN                       NaN
# 984           NaN       BROOKLYN                       NaN
# 985           NaN         QUEENS                       NaN
# 986  2.030310e+09          BRONX                       NaN
# 987  1.015810e+09      MANHATTAN                       NaN
# 988  2.032520e+09          BRONX                       NaN
# 989  3.051610e+09       BROOKLYN                       NaN
# 990  3.021060e+09       BROOKLYN                       NaN
# 991  3.068990e+09       BROOKLYN                       NaN
# 992  3.030730e+09       BROOKLYN                       NaN
# 993           NaN      MANHATTAN                       NaN
# 994           NaN          BRONX                       NaN
# 995  2.033320e+09          BRONX                       NaN
# 996  2.032500e+09          BRONX                       NaN
# 997  4.022810e+09         QUEENS                       NaN
# 998  3.014420e+09       BROOKLYN                       NaN
# 999  3.039120e+09       BROOKLYN                       NaN
#
#      bridge_highway_name bridge_highway_segment                 city  \
# 0                    NaN         1-1-1671254420                  NaN
# 1                    NaN                    NaN             BROOKLYN
# 2                    NaN                    NaN             NEW YORK
# 3                    NaN                    NaN             BROOKLYN
# 4                    NaN                    NaN             BROOKLYN
# 5                    NaN                    NaN             BROOKLYN
# 6                    NaN                    NaN                BRONX
# 7                    NaN                    NaN                  NaN
# 8                    NaN                    NaN             Rosedale
# 9                    NaN                    NaN                BRONX
# 10                   NaN                    NaN             NEW YORK
# 11                   NaN                    NaN             NEW YORK
# 12                   NaN                    NaN             NEW YORK
# 13                   NaN                    NaN  Springfield Gardens
# 14                   NaN                    NaN        STATEN ISLAND
# 15                   NaN                    NaN        STATEN ISLAND
# 16                   NaN                    NaN        FRESH MEADOWS
# 17                   NaN                    NaN        STATEN ISLAND
# 18                   NaN                    NaN             NEW YORK
# 19                   NaN                    NaN             NEW YORK
# 20                   NaN                    NaN             BROOKLYN
# 21                   NaN                    NaN             BROOKLYN
# 22                   NaN                    NaN             BROOKLYN
# 23                   NaN                    NaN             NEW YORK
# 24                   NaN                    NaN         Howard Beach
# 25                   NaN                    NaN        STATEN ISLAND
# 26                   NaN                    NaN             BROOKLYN
# 27                   NaN                    NaN                BRONX
# 28                   NaN                    NaN            RIDGEWOOD
# 29                   NaN                    NaN             NEW YORK
# ..                   ...                    ...                  ...
# 970                  NaN                    NaN             NEW YORK
# 971                  NaN                    NaN                BRONX
# 972                  NaN                    NaN                BRONX
# 973                  NaN                    NaN             NEW YORK
# 974                      NaN                       NaN
# 975               132 STREET                133 STREET
# 976                      NaN                       NaN
# 977                      NaN                       NaN
# 978                      NaN                       NaN
# 979                      NaN                       NaN
# 980                      NaN                       NaN
# 981                      NaN                       NaN
# 982                      NaN                       NaN
# 983                 AVENUE Y                  AVENUE Z
# 984                      NaN                       NaN
# 985                      NaN                       NaN
# 986                      NaN                       NaN
# 987                      NaN                       NaN
# 988                     BEND  VAN CORTLANDT PARK SOUTH
# 989                      NaN                       NaN
# 990            FULTON STREET          LAFAYETTE AVENUE
# 991              BATH AVENUE             HARWAY AVENUE
# 992           JOHNSON AVENUE             BOERUM STREET
# 993                      NaN                       NaN
# 994                      NaN                       NaN
# 995                      NaN                       NaN
# 996                      NaN                       NaN
# 997                      NaN                       NaN
# 998                      NaN                       NaN
# 999                      NaN                       NaN
#
#                                             descriptor  \
# 0                                       Administration
# 1                            Leak (Use Comments) (WA2)
# 2                             Condo or Co-op Abatement
# 3                                      ENTIRE BUILDING
# 4                                 14 Derelict Vehicles
# 5                                 14 Derelict Vehicles
# 6                     15 Street Cond/Dump-Out/Drop-Off
# 7                                             Graffiti
# 8                                              Pothole
# 9                                       APARTMENT ONLY
# 10                                             Pothole
# 11        Noise: Construction Before/After Hours (NM1)
# 12                                            Graffiti
# 13                                             Pothole
# 14                                  With License Plate
# 15                                  With License Plate
# 16                            Unauthorized Bus Layover
# 17                                             Pothole
# 18                               Hydrant Running (WC3)
# 19                Lead Kit Request (Residential) (L10)
# 20                       missed collection for E-waste
# 21                Lead Kit Request (Residential) (L10)
# 22                     Odor In Sewer/Catch Basin (ICB)
# 23                                    Dirty Water (WE)
# 24   No Certificate Of Occupancy/Illegal/Contrary T...
# 25                           Billing Address Incorrect
# 26                                     12 Dead Animals
# 27                               Other (Explain Below)
# 28                                     Blocked Hydrant
# 29                    15 Street Cond/Dump-Out/Drop-Off
# ..                                                 ...
# 970                                          No Access
# 971                                    ENTIRE BUILDING
# 972                                    ENTIRE BUILDING
# 973                                    ENTIRE BUILDING
# 974                                                NaN
# 975                               14 Derelict Vehicles
# 976                                     APARTMENT ONLY
# 977                                            CABINET
# 978                                          SLOW LEAK
# 979                                           LIGHTING
# 980                                    ENTIRE BUILDING
# 981                                    ENTIRE BUILDING
# 982                                     APARTMENT ONLY
# 983                                    12 Dead Animals
# 984                     Double Parked Blocking Traffic
# 985                                    ENTIRE BUILDING
# 986                                       REFRIGERATOR
# 987                                    ENTIRE BUILDING
# 988                     Double Parked Blocking Vehicle
# 989                                    ENTIRE BUILDING
# 990                                     Partial Access
# 991                                          No Access
# 992                                   Loud Music/Party
# 993                                           Graffiti
# 994                                   Street Light Out
# 995                                     APARTMENT ONLY
# 996                                    ENTIRE BUILDING
# 997                                    ENTIRE BUILDING
# 998                                    ENTIRE BUILDING
# 999                Working Contrary To Stop Work Order
#
#                     due_date facility_type           incident_address  \
# 0    2019-01-31T13:32:55.000           NaN                        NaN
# 1                        NaN           NaN              257 92 STREET
# 992       NaN  40.706375   POINT (-73.93897659776 40.706375491924)
# 993       NaN        NaN                                       NaN
# 994       NaN        NaN                                       NaN
# 995       NaN  40.871956  POINT (-73.878969013957 40.871956223913)
# 996       NaN  40.872981  POINT (-73.899776290605 40.872980729368)
# 997       NaN  40.741939  POINT (-73.916104414483 40.741938657646)
# 998       NaN  40.674744  POINT (-73.909018420836 40.674744183114)
# 999       NaN  40.684167   POINT (-73.88187704292 40.684167037544)
#
#      location_address  location_city  location_state  \
# 0                 NaN            NaN             NaN
# 1                 NaN            NaN             NaN
# 2                 NaN            NaN             NaN
# 3                 NaN            NaN             NaN
# 4                 NaN            NaN             NaN
# 5                 NaN            NaN             NaN
# 6                 NaN            NaN             NaN
# 7                 NaN            NaN             NaN
# 8                 NaN            NaN             NaN
# 9                 NaN            NaN             NaN
# 10                NaN            NaN             NaN
# 11                NaN            NaN             NaN
# 12                NaN            NaN             NaN
# 13                NaN            NaN             NaN
# 14                NaN            NaN             NaN
# 15                NaN            NaN             NaN
# 16                NaN            NaN             NaN
# 17                NaN            NaN             NaN
# 18                NaN            NaN             NaN
# 19                NaN            NaN             NaN
# 20                NaN            NaN             NaN
# 21                NaN            NaN             NaN
# 22                NaN            NaN             NaN
# 23                NaN            NaN             NaN
# 24                NaN            NaN             NaN
# 25                NaN            NaN             NaN
# 26                NaN            NaN             NaN
# 27                NaN            NaN             NaN
# 28                NaN            NaN             NaN
# 29                NaN            NaN             NaN
# ..                ...            ...             ...
# 970               NaN            NaN             NaN
# 971               NaN            NaN             NaN
# 972               NaN            NaN             NaN
# 973               NaN            NaN             NaN
# 974               NaN            NaN             NaN
# 975               NaN            NaN             NaN
# 976               NaN            NaN             NaN
# 977               NaN            NaN             NaN
# 978               NaN            NaN             NaN
# 979               NaN            NaN             NaN
# 980               NaN            NaN             NaN
# 981               NaN            NaN             NaN
# 982               NaN            NaN             NaN
# 983               NaN            NaN             NaN
# 984               NaN            NaN             NaN
# 985               NaN            NaN             NaN
# 986               NaN            NaN             NaN
# 987               NaN            NaN             NaN
# 988               NaN            NaN             NaN
# 989               NaN            NaN             NaN
# 990               NaN            NaN             NaN
# 991               NaN            NaN             NaN
# 992               NaN            NaN             NaN
# 993               NaN            NaN             NaN
# 994               NaN            NaN             NaN
# 995               NaN            NaN             NaN
# 996               NaN            NaN             NaN
# 997               NaN            NaN             NaN
# 998               NaN            NaN             NaN
# 999               NaN            NaN             NaN
#
#                     location_type  location_zip  longitude  \
# 0                             NaN           NaN        NaN
# 1                             NaN           NaN -74.033957
# 2                      Condo Unit           NaN        NaN
# 3            RESIDENTIAL BUILDING           NaN -73.951342
# 4                          Street           NaN -73.949585
# 5                          Street           NaN -73.919425
# 6                          Street           NaN -73.929437
# 7                             NaN           NaN        NaN
# 8                             NaN           NaN -73.744821
# 9            RESIDENTIAL BUILDING           NaN -73.918671
# 10                            NaN           NaN -73.925513
# 11                            NaN           NaN -73.923629
# 12                      Mixed Use           NaN -73.989813
# 13                            NaN           NaN -73.765584
# 14                Street/Sidewalk           NaN -74.135887
# 15                Street/Sidewalk           NaN -74.143718
# 16                Street/Sidewalk           NaN -73.809697
# 17                            NaN           NaN -74.241424
# 18                            NaN           NaN -73.937562
# 19                            NaN           NaN -73.976829
# 20                       Sidewalk           NaN -73.913713
# 21                            NaN           NaN -73.922451
# 22                            NaN           NaN -73.948415
# 23                            NaN           NaN -73.980708
# 24                            NaN           NaN -73.840620
# 25               Property Address           NaN        NaN
# 26                       Sidewalk           NaN -73.981561
# 27   3+ Family Apartment Building           NaN -73.908363
# 28                Street/Sidewalk           NaN -73.892917
# 29                         Street           NaN -73.989871
# ..                            ...           ...        ...
# 970               Street/Sidewalk           NaN -73.940332
# 971          RESIDENTIAL BUILDING           NaN -73.889279
# 972          RESIDENTIAL BUILDING           NaN -73.907754
# 973          RESIDENTIAL BUILDING           NaN -73.918889
# 974               Street/Sidewalk           NaN -73.953933
# 975                        Street           NaN -73.806162
# 976          RESIDENTIAL BUILDING           NaN -73.943853
# 977          RESIDENTIAL BUILDING           NaN -73.857127
# 978          RESIDENTIAL BUILDING           NaN -73.914327
# 979          RESIDENTIAL BUILDING           NaN -73.922751
# 980          RESIDENTIAL BUILDING           NaN -73.856458
# 981          RESIDENTIAL BUILDING           NaN -73.908895
# 982          RESIDENTIAL BUILDING           NaN -73.904967
# 983                      Sidewalk           NaN -73.942989
# 984               Street/Sidewalk           NaN -73.986692
# 985          RESIDENTIAL BUILDING           NaN -73.837429
# 986          RESIDENTIAL BUILDING           NaN -73.893814
# 987          RESIDENTIAL BUILDING           NaN -73.946803
# ...
# 982        2019-01-17T10:40:59.000
# 983        2019-01-16T14:56:00.000
# 984        2019-01-17T17:34:17.000
# 985        2019-01-17T23:28:07.000
# 986        2019-01-17T08:36:35.000
# 987        2019-01-17T17:08:49.000
# 988        2019-01-17T17:43:25.000
# 989        2019-01-17T18:13:57.000
# 990        2019-01-17T14:36:44.000
# 991        2019-01-17T20:18:29.000
# 992        2019-01-17T04:28:10.000
# 993        2019-01-17T09:49:29.000
# 994        2019-01-17T00:30:00.000
# 995        2019-01-17T02:08:35.000
# 996        2019-01-17T02:08:09.000
# 997        2019-01-17T10:39:15.000
# 998        2019-01-17T18:20:29.000
# 999        2019-01-17T00:00:00.000
#
#                                 resolution_description  road_ramp      status  \
# 0    Your comments have been submitted to the Depar...        NaN  Email Sent
# 1    The Department of Environmental Protection has...        NaN      Closed
# 2                                           See notes.        NaN      Closed
# 3    The Department of Housing Preservation and Dev...        NaN      Closed
# 4      The Department of Sanitation removed the items.        NaN     Pending
# 5      The Department of Sanitation removed the items.        NaN     Pending
# 6      The Department of Sanitation removed the items.        NaN      Closed
# 7                                                  NaN        NaN        Open
# 8    The Department of Transportation inspected thi...        NaN      Closed
# 9    The Department of Housing Preservation and Dev...        NaN      Closed
# 10   The Department of Transportation inspected thi...        NaN        Open
# 11   The Department of Environmental Protection det...        NaN      Closed
# 12   The graffiti on this property has been schedul...        NaN        Open
# 13   The Department of Transportation inspected thi...        NaN      Closed
# 14   The Police Department responded to the complai...        NaN      Closed
# 15   The Police Department responded to the complai...        NaN      Closed
# 16   The Police Department responded to the complai...        NaN      Closed
# 17   The Department of Transportation inspected thi...        NaN      Closed
# 18   The Department of Environmental Protection has...        NaN      Closed
# 19                                                 NaN        NaN        Open
# 20   The Department of Sanitation did not find any ...        NaN      Closed
# 21                                                 NaN        NaN        Open
# 22                                                 NaN        NaN        Open
# 23   The Department of Environmental Protection inv...        NaN      Closed
# 24   The Department of Buildings investigated this ...        NaN    Assigned
# 25                                          See notes.        NaN      Closed
# 26   The Department of Sanitation cleaned the locat...        NaN      Closed
# 27   The Department of Health and Mental Hygiene wi...        NaN      Closed
# 28   The Police Department issued a summons in resp...        NaN      Closed
# 29     The Department of Sanitation removed the items.        NaN      Closed
# ..                                                 ...        ...         ...
# 970  The Police Department responded to the complai...        NaN      Closed
# 971  The Department of Housing Preservation and Dev...        NaN      Closed
# 972  The Department of Housing Preservation and Dev...        NaN      Closed
# 973  The Department of Housing Preservation and Dev...        NaN      Closed
# 974  The Police Department responded to the complai...        NaN      Closed
# 975    The Department of Sanitation removed the items.        NaN     Pending
# 976  The Department of Housing Preservation and Dev...        NaN      Closed
# 977  The Department of Housing Preservation and Dev...        NaN      Closed
# 978  The Department of Housing Preservation and Dev...        NaN      Closed
# 979  The Department of Housing Preservation and Dev...        NaN      Closed
# 980  The Department of Housing Preservation and Dev...        NaN      Closed
# 981  The Department of Housing Preservation and Dev...        NaN      Closed
# 982  The Department of Housing Preservation and Dev...        NaN      Closed
# 983    The Department of Sanitation removed the items.        NaN      Closed
# 984  The Police Department responded and upon arriv...        NaN      Closed
# 985  The Department of Housing Preservation and Dev...        NaN      Closed
# 986  The Department of Housing Preservation and Dev...        NaN      Closed
# 987  The Department of Housing Preservation and Dev...        NaN      Closed
# 988  The Police Department responded to the complai...        NaN      Closed
# 989  The Department of Housing Preservation and Dev...        NaN      Closed
# 990  The Police Department responded to the complai...        NaN      Closed
# 991  The Police Department responded to the complai...        NaN      Closed
# 992  The Police Department responded and upon arriv...        NaN      Closed
# 993                                                NaN        NaN        Open
# 994  Service Request status for this request is ava...        NaN      Closed
# 995  The Department of Housing Preservation and Dev...        NaN      Closed
# 996  The Department of Housing Preservation and Dev...        NaN      Closed
# 997  The Department of Housing Preservation and Dev...        NaN      Closed
# 998  The Department of Housing Preservation and Dev...        NaN      Closed
# 999  The Department of Buildings investigated this ...        NaN      Closed
#
#               street_name  taxi_company_borough  taxi_pick_up_location  \
# 0                     NaN                   NaN                    NaN
# 1               92 STREET                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3         EASTERN PARKWAY                   NaN                    NaN
# 4        EAST   23 STREET                   NaN                    NaN
# 5         PALMETTO STREET                   NaN                    NaN
# 6       UNIVERSITY AVENUE                   NaN                    NaN
# 7           444 14 street                   NaN                    NaN
# 8          BAYVIEW AVENUE                   NaN                    NaN
          "$where=date_extract_y(created_date)=2017" \
          "&$select=count(created_date)"
resp = requests.get(apiURL, headers=HEADERS)
totalRecords = int(resp.text.split('"')[-2])

# Look through column fields to see which data may/not be relevant, get indices.
for idx, col in enumerate(resp_df.columns):
    print(idx, col)
# Out:
# 0 address_type
# 1 agency
# 2 agency_name
# 3 bbl
# 4 borough
# 5 bridge_highway_direction
# 6 bridge_highway_name
# 7 bridge_highway_segment
# 8 city
# 9 closed_date
# 10 community_board
# 11 complaint_type
# 12 created_date
# 13 cross_street_1
# 14 cross_street_2
# 15 descriptor
# 16 due_date
# 17 facility_type
# 18 incident_address
# 19 incident_zip
# 20 intersection_street_1
# 21 intersection_street_2
# 22 landmark
# 23 latitude
# 24 location
# 25 location_address
# 26 location_city
# 27 location_state
# 28 location_type
# 29 location_zip
# 30 longitude
# 31 open_data_channel_type
# 32 park_borough
# 33 park_facility_name
# 34 resolution_action_updated_date
# 35 resolution_description
# 36 road_ramp
# 37 status
# 38 street_name
# 39 taxi_company_borough
# 40 taxi_pick_up_location
# 41 unique_key
# 42 vehicle_type
# 43 x_coordinate_state_plane
# 44 y_coordinate_state_plane

# %% [markdown]
# ### Sources
#
# There are 2 options for obtaining this NYC 311 data:
# 1. Download the full dataset (CSV file)
# 2. Use the Socrata API to query for the data
#
# The full dataset is prohibitively large for my working environment, so I'm choosing the API route. I'm limiting each request to 50,000 records (the max value for v2.0 of this API. I *believe* this endpoint is 2.1 and has no such limit, but I'll keep it to be safe), and will be paging through the data. A count query shows that there are ~2.4M records for 2017, so I'll need to be a little structured about how I make the query.
#
# Most requests finish in a few seconds, but the server seem to does slow down (~30s per request) once I reach about 2M records. This typically finishes in 5 minutes. I currently only kill the process on an unsuccessul response code, but more handling should be implemented for other codes and timeouts. The complete dataframe will get stored to a pickle file to avoid making these API requests for repeated runs.
#
# I initially downloaded the full records so I could have more data to cross-reference for cleaning purposes (i.e. fill in missing zip code and borough fields). Currently when I convert to a dataframe, I throw most of this data away, but this could be used if a more thorough cleaning were undertaken.
#
# Most columns have data of mixed type, so I opted to let Pandas assign a dtype of object/string. I do set the dtype as a string for the zip code since I don't need to do any numeric processing on it and several entries have non-numeric characters.

# %%
def buildNYCData(numRows):
    df_list = list()
    
    numOffset = 0
    count = numRows

    start = time.time()
    apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?" \
             "$where=date_extract_y(created_date)=2017" \
             "&$select=count(created_date)"
    resp = requests.get(apiURL, headers=HEADERS)
    timeElapsed(start)
    print(resp.text.split('"')[-2], 'total records\n')

    while count == numRows:
        apiURL = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?" \
                 "$where=date_extract_y(created_date)=2017" \
                 "&$limit=" + str(numRows) + "&$offset=" + str(numOffset)
        
        start = time.time()
        resp = requests.get(apiURL, headers=HEADERS)
        timeElapsed(start)

        print(str(resp.status_code), ': records =', numOffset+numRows)
        if resp.status_code != 200:
            print('API request failed')
            break

        start = time.time()
        csvIO = StringIO(resp.text)
        df_list.append(pd.read_csv(csvIO, dtype={'incident_zip':str},
                       usecols=['borough', 'city', 'complaint_type', 'created_date', 'incident_zip']) \
                               [['created_date', 'complaint_type', 'incident_zip', 'borough', 'city']])
                       #, low_memory=False))# Keeping the warnings

        timeElapsed(start)
        print('\n')
        
        count = df_list[-1].shape[0]
        numOffset += count
        
    return pd.concat(df_list, ignore_index=True)

# %%
numRows = 50000

# Don't query the data for repeated runs
if os.path.isfile('nyc1_df.pkl'):
    nyc1_df = pd.read_pickle('nyc1_df.pkl')
else:
    nyc1_df = buildNYCData(numRows)
# Out:
# 00:00
# 2461208 total records
#
# 00:01
# 200 : records = 50000
# 00:00
#
#
# 00:01
# 200 : records = 100000
# 00:00
#
#
# 00:02
# 200 : records = 150000
# 00:00
#
#
# 00:02
# 200 : records = 200000
# 00:00
#
#
# 00:01
# 200 : records = 250000
# 00:00
#
#
# 00:06
# 200 : records = 300000
# 00:00
#
#
# 00:02
# 200 : records = 350000
# 00:00
#
#
# 00:02
# 200 : records = 400000
# 00:00
#
#
# 00:04
# 200 : records = 450000
# 00:00
#
#
# 00:08
# 200 : records = 500000
# 00:00
#
#
# 00:02
# 200 : records = 550000
# /Users/master/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# 00:00
#
#
# 00:01
# 200 : records = 600000
# 00:00
#
#
# 00:02
# 200 : records = 650000
# 00:00
#
#
# 00:01
# 200 : records = 700000
# 00:00
#
#
# 00:01
# 200 : records = 750000
# 00:00
#
#
# 00:01
# 200 : records = 800000
# 00:00
#
#
# 00:01
# 200 : records = 850000
# 00:00
#
#
# 00:01
# 200 : records = 900000
# 00:00
#
#
# 00:02
# 200 : records = 950000
# 00:00
#
#
# 00:02
# 200 : records = 1000000
# 00:00
#
#
# 00:02
# 200 : records = 1050000
# 00:00
#
#
# 00:01
# 200 : records = 1100000
# 00:00
#
#
# 00:02
# 200 : records = 1150000
# 00:00
#
#
# 00:02
# 200 : records = 1200000
# 00:00
#
#
# 00:02
# 200 : records = 1250000
# 00:00
#
#
# 00:01
# 200 : records = 1300000
# 00:00
#
#
# 00:01
# 200 : records = 1350000
# 00:00
#
#
# 00:02
# 200 : records = 1400000
# 00:00
#
#
# 00:02
# 200 : records = 1450000
# 00:00
#
#
# 00:02
# 200 : records = 1500000
# 00:00
#
#
# 00:02
# 200 : records = 1550000
# 00:00
#
#
# 00:02
# 200 : records = 1600000
# 00:00
#
#
# 00:01
# 200 : records = 1650000
# 00:00
#
#
# 00:02
# 200 : records = 1700000
# 00:00
#
#
# 00:03
# 200 : records = 1750000
# 00:00
#
#
# 00:01
# 200 : records = 1800000
# 00:00
#
#
# 00:01
# 200 : records = 1850000
# 00:00
#
#
# 00:02
# 200 : records = 1900000
# 00:00
#
#
# 00:01
# 200 : records = 1950000
# 00:00
#
#
# 00:03
# 200 : records = 2000000
# 00:00
#
#
# 00:02
# 200 : records = 2050000
# 00:00
#
#
# 00:01
# 200 : records = 2100000
# 00:00
#
#
# 00:01
# 200 : records = 2150000
# 00:00
#
#
# 00:01
# 200 : records = 2200000
# 00:00
#
#
# 00:04
# 200 : records = 2250000
# 00:00
#
#
# 00:02
# 200 : records = 2300000
# 00:00
#
#
# 00:01
# 200 : records = 2350000
# 00:00
#
#
# 00:01
# 200 : records = 2400000
# 00:00
#
#
# 00:01
# 200 : records = 2450000
# 00:00
#
#
# 00:00
# 200 : records = 2500000
# 00:00

# %%
# Store in pickle file locally before cleanup
nyc1_df.to_pickle('nyc1_df.pkl')

# %% [markdown]
#  Now to inspect data and look for missing fields...
#
# ### complaint_type
#
# As seen in the count list below, there are what seems to be duplicates (e.g. `'UNSANITARY CONDITION'` and `'Sanitation condition'`); however, the 311 submission fields online have categories and *subcategories*, many of which seem to change or be user submitted. These records seem to only have the subcategory, and so without context, it's possible I could be mixing complaints from entirely separate categories if I tried any combining.
#
# I will, however, convert these strings to a uniform case to catch any matching categories. This will catch some extra `'PLUMBING'` complaints for example, but it falls outside the top 10.

# %%
nyc1_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# Noise - Residential                    229314
# HEAT/HOT WATER                         210158
# Illegal Parking                        147525
# Blocked Driveway                       137547
# Street Condition                        98622
# UNSANITARY CONDITION                    81801
# Street Light Condition                  81537
# Noise - Street/Sidewalk                 72629
# Water System                            62853
# Noise                                   62191
# PAINT/PLASTER                           59566
# PLUMBING                                50781
# Request Large Bulky Item Collection     49057
# Noise - Commercial                      46997
# Sanitation Condition                    40665
# General Construction/Plumbing           39503
# Missed Collection (All Materials)       37933
# Dirty Conditions                        37446
# Rodent                                  36958
# DOOR/WINDOW                             36347
# Name: complaint_type, dtype: int64

# %%
# Look at count list again after str.upper()
nyc1_df['complaint_type'] = nyc1_df['complaint_type'].str.upper()
nyc1_df['complaint_type'].value_counts(dropna=False).head(20)
# Out:
# NOISE - RESIDENTIAL                    229314
# HEAT/HOT WATER                         210158
# ILLEGAL PARKING                        147525
# BLOCKED DRIVEWAY                       137547
# STREET CONDITION                        98622
# UNSANITARY CONDITION                    81801
# STREET LIGHT CONDITION                  81537
# NOISE - STREET/SIDEWALK                 72629
# WATER SYSTEM                            62853
# NOISE                                   62191
# PAINT/PLASTER                           59566
# PLUMBING                                56893
# REQUEST LARGE BULKY ITEM COLLECTION     49057
# NOISE - COMMERCIAL                      46997
# SANITATION CONDITION                    40665
# GENERAL CONSTRUCTION/PLUMBING           39503
# MISSED COLLECTION (ALL MATERIALS)       37933
# DIRTY CONDITIONS                        37446
# RODENT                                  36958
# DOOR/WINDOW                             36347
# Name: complaint_type, dtype: int64

# %% [markdown]
# ### borough
#
# There are "unspecified" boroughs that could likely be inferred from **incident_zip**, and that will be done later on with the aid of the NYC borough/zip code database.
#
# Otherwise, there are *many* fields that could be used to fill in the blank (city, cross streets, intersection streets, park borough, etc.). Without more context from NYC 311's info page, it's unclear how to best correlate this data.

# %%
nyc1_df['borough'].value_counts(dropna=False)
# Out:
# BROOKLYN         768828
# QUEENS           593648
# MANHATTAN        481812
# BRONX            455109
# STATEN ISLAND    129194
# Unspecified       32617
# Name: borough, dtype: int64

# %%
bor_missing = len(nyc1_df[nyc1_df['borough'] == 'Unspecified'])
print('{} of {} borough records are missing. This represents {:.3f}% of our data.'
      .format(bor_missing, totalRecords, float(100*bor_missing)/totalRecords))

zip_fix = len(nyc1_df[(nyc1_df['incident_zip'].notna()) & (nyc1_df['borough'] == 'Unspecified')])
print('{} of these {} missing borough entries could be inferred from an available zip code.'
      .format(zip_fix, bor_missing))
print('This could correct up to {:.3f}% of our missing borough data'
      .format(100*float(zip_fix)/bor_missing))
# Out:
# 32617 of 2461208 borough records are missing. This represents 1.325% of our data.
# 3781 of these 32617 missing borough entries could be inferred from an available zip code.
# This could correct up to 11.592% of our missing borough data

# %% [markdown]
# ### incident_zip
#
# There are many missing and irregular entries for this field. I'm not sure there's a clear answer to filling in this data.
#
# Clean up will involve making sure all zip codes are numeric and 5 characters or less.

# %%
nyc1_df['incident_zip'].value_counts(dropna=False)
# Out:
# NaN           96625
# 11226         42438
# 11385         35893
# 10467         34065
# 11207         31436
# 10452         29896
# 10458         29797
# 10453         29571
# 10468         28952
# 11208         28358
# 10456         26918
# 10031         26785
# 10457         26752
# 11221         25900
# 11225         25803
# 11206         25595
# 11213         24633
# 11234         24109
# 10472         23875
# 11212         23765
# 11209         23722
# 11203         23699
# 11233         23441
# 11216         22945
# 10314         22281
# 11215         22076
# 11220         22008
# 11230         21893
# 10032         21641
# 10466         21544
#               ...
# 60604             1
# 10567             1
# 10510             1
# 08063             1
# 43226             1
# 91716-0500        1
# 30006             1
# 07002             1
# 33131             1
# 10159             1
# 10853             1
# 10401             1
# 14901             1
# 11771             1
# 11010             1
# 80235             1
# 07108             1
# 13903             1
# 01234             1
# 05620             1
# 20049             1
# 10514             1
# 28901             1
# 11590             1
# 07111             1
# 43017             1
# 07007             1
# 06831             1
# 30010             1
# 11749             1
# Name: incident_zip, Length: 505, dtype: int64

# %%
zip_missing = len(nyc1_df[nyc1_df['incident_zip'].isna()])
print('{} of {} zip code records are missing. This represents {:.3f}% of our data.'
      .format(zip_missing, totalRecords, float(100*zip_missing)/totalRecords))
# Out:
# 96625 of 2461208 zip code records are missing. This represents 3.926% of our data.

# %% [markdown]
# ## 2010 Census Population Data
#
# This database is available at Splitwise blog and contains US zip codes and population from the 2010 Census.

# %%
censusURL = "https://s3.amazonaws.com/SplitwiseBlogJB/2010+Census+Population+By+Zipcode+(ZCTA).csv"
census_df = pd.read_csv(censusURL, dtype={'Zip Code ZCTA':str})
census_df.head(10)
# Out:
#   Zip Code ZCTA  2010 Census Population
# 0         01001                   16769
# 1         01002                   29049
# 2         01003                   10372
# 3         01005                    5079
# 4         01007                   14649
# 5         01008                    1263
# 6         01009                     741
# 7         01010                    3609
# 8         01011                    1370
# 9         01012                     661

# %%
# Some zip codes are listed twice. Checked all zips that start with '100', '10', '11'. No duplicates.
census_df[census_df['Zip Code ZCTA'].str.startswith('11')]['Zip Code ZCTA'].value_counts();

# %%
# Write to file
census_df.to_pickle('census_df.pkl')

# %% [markdown]
# ## Zip codes for NYC boroughs
#
# This dataset will be needed to match zip codes from the Census dataset with its NYC borough. This is being read from an html table from an NYC enthusiast site. The online formatting will require some transformation here.

# %%
zipsURL = "https://www.nycbynatives.com/nyc_info/new_york_city_zip_codes.php"
zips_df = pd.read_html(zipsURL, match='10001')[0]
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 5 columns
#         0          1   2      3      4
# 0   10001  Manhattan NaN  10451  Bronx
# 1   10002  Manhattan NaN  10452  Bronx
# 2   10003  Manhattan NaN  10453  Bronx
# 3   10004  Manhattan NaN  10454  Bronx
# 4   10005  Manhattan NaN  10455  Bronx
# 5   10006  Manhattan NaN  10456  Bronx
# 6   10007  Manhattan NaN  10457  Bronx
# 7   10009  Manhattan NaN  10458  Bronx
# 8   10010  Manhattan NaN  10459  Bronx
# 9   10011  Manhattan NaN  10460  Bronx
# 10  10012  Manhattan NaN  10461  Bronx
# 11  10013  Manhattan NaN  10462  Bronx
# 12  10014  Manhattan NaN  10463  Bronx
# 13  10015  Manhattan NaN  10464  Bronx
# 14  10016  Manhattan NaN  10465  Bronx
# 15  10017  Manhattan NaN  10466  Bronx
# 16  10018  Manhattan NaN  10467  Bronx
# 17  10019  Manhattan NaN  10468  Bronx
# 18  10020  Manhattan NaN  10469  Bronx
# 19  10021  Manhattan NaN  10470  Bronx

# %%
# The table is displayed twice in different order. Only need one side.
zips_df.drop(labels=[2,3,4], axis='columns', inplace=True)
print('{} rows x {} columns'.format(zips_df.shape[0], zips_df.shape[1]))
zips_df.head(20)
# Out:
# 240 rows x 2 columns
#         0          1
# 0   10001  Manhattan
# 1   10002  Manhattan
# 2   10003  Manhattan
# 3   10004  Manhattan
# 4   10005  Manhattan
# 5   10006  Manhattan
# 6   10007  Manhattan
# 7   10009  Manhattan
# 8   10010  Manhattan
# 9   10011  Manhattan
# 10  10012  Manhattan
# 11  10013  Manhattan
# 12  10014  Manhattan
# 13  10015  Manhattan
# 14  10016  Manhattan
# 15  10017  Manhattan
# 16  10018  Manhattan
# 17  10019  Manhattan
# 18  10020  Manhattan
# 19  10021  Manhattan

# %%
# Rename columns and check borough values
zips_df.set_axis(['zip_code', 'borough'], axis='columns', inplace=True)
zips_df['borough'].value_counts()
# Out:
# Manhattan    96
# Queens       63
# Brooklyn     43
# Bronx        25
# Staten       13
# Name: borough, dtype: int64

# %%
# Will convert to uppercase and fix 'Staten' for consistency with previous datasets
zips_df['borough'] = zips_df['borough'].str.upper()
zips_df.loc[zips_df['borough'] == 'STATEN', 'borough'] = 'STATEN ISLAND'

# Convert zip code dtype to string
zips_df['zip_code'] = zips_df['zip_code'].astype(str)

# %%
#  Write to file
zips_df.to_pickle('zips_df.pkl')

# %%
# Write cleaned up NYC dataframe to separate file
nyc1_df.to_pickle('nyc2_df.pkl')
